# %% [markdown]
# # 📓-1️⃣ QuickStart

# %% [markdown]
# <div style="font-size:20px;font-weight:bold;background-color:cyan;color:darkmagenta">
# <a href="https://docs.manim.community/en/stable/installation/uv.html">Installation Manim Community link</a><br></div><hr>

# %% [markdown]
# <div style="font-size:20px;font-weight:bold;background-color:indigo">export video quality</div>
# <div style="background-color:green"><p>&emsp;syntax: manim <b>-pqk filename.py scenename</p>
# <ul>
# <li><div style="font-size:20px;color:white;background-color:indigo;
#         font-weight:bold">-fqk&nbsp;&nbsp;f-file folder| <br>-pqk p-preview | <br>-ps savelastframe as picture|<br>--a render all scene classes|<br>--format  default is .mp4</div>
# </li>
# <li><span style="color:red">-pql  specifies low render quality (854x480 15FPS) &nbsp;-only for rapid testing</span></li><hr>
# <li>-pqm, medium (1280x720 30FPS) </li>
# <li>-pqh, high (1920x1080 60FPS) </li>
# <li>-pqp, 2k premium  (2048 x 1080 60FPS) </li>
# <li>-pqp  4k (3840 x 2160 60FPS) </li><hr>
# <li><mark><b>Why scenename is needed in the syntax</b></mark>: its because we can put many scenes within a  <br>single python file and call upon them individually</li><li>we can also use section to generate and concatenation multiple video to form a single output</li>
# <li><span style="color:cyan">-pqk, 4k quality (3840x2160 60FPS)  &emsp;&emsp;&emsp;  &emsp; &emsp;&emsp;-ideal for output</span></li>
# </ul></div><hr>

# %% [markdown]
# <div style="background-color:darkmagenta;font-size:20px;color:beige">section </div>
# <ol>
# <li>syntax</li>
#     <ul>
#         <li>manim --save_sections section.py</li>
#     </ul>
# <li>code demo</li>
#         <ul>
#         <li>class scenename(Scene) </li>
#         <li>&emsp;def construct(self)</li><hr>
#             <ol>
#                 <li>self.next_section()</li><hr>
#                         <ul>
#                             <li>code</li>
#                             <li>code</li>
#                             <li>code</li>
#                             <li>--</li>
#                         </ul>
#                 <li>self.next_section()</li><hr>
#                 <li>--</li><hr>
#                 <li>self.next_section(skip_animations=True)</li><hr>
#             </ol>
# </ol>
# <hr>

# %% [markdown]
# <div style="background-color:green;font-size:20px;color:beige">Plot Workfolow </div>
# <ol>
# <li>ax &emsp; &rarr; ax object from Axes calss by specifying x_range and y_range </li>
# <li>curve &rarr; ax.plot(equation using lambda x:(x-2)*x*(x+2)/2)</li>
# <li>area &nbsp; &rarr; ax.get_area(curve,x_range())</li>
# <li>add &nbsp; &rarr; play </li>
# </ol>
# <hr>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example One: Create a circle | Code Explanation </div>
# %%manim -qm <u>CreateCircle</u><br>
# class <u>CreateCircle</u>(<span style="color:cyan;backrgound-color:blue">Scene):  ⇆ Comment object capitalized</span><br>
#     &emsp;    &emsp;<span style="color:red;backrgound-color:blue">def construct(self):</span><br>
#     &emsp;    &emsp;       <span style="color:yellow"><u>circle</u></span> = <span style="color:cyan;backrgound-color:blue">Circle</span>(color=PINK, fill_opacity=0.5) <br>
#         &emsp;    &emsp;    self.play(<span style="color:darkmagenta;backgroun-color:white">Create</span>( <span style="color:yellow"><u>circle</u></span>)) <br>
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;font-size:20px;
#              border:2px double white; padding:2px">workflow</span><br>
# You run your animation in class using construct method    :        &emsp;<br> self.play() | self.add(Create(mobject))
# <br> Scene is the canvas that you place object and play animation
# <hr>process of initializing an instance of a manim object <br>manim object variable =Mobject_class with capitalized initial letter(parameter=ARGUMENTS,&emsp;
# <span style="color:darkmagenta;background-color:cyan;font-weight:bold">fill_opacity=range(0-1))</span> &emsp; <br>with 0 no fill to 1 full-fill <br>tansparency is 0: Therefore, the fill_opacity parameter is &emsp;<br>
# <span style="color:darkmagenta;background-color:cyan;font-weight:bold">in inverse relationship with transparency percentage</span> in excle ,<br> which means the higher the value between 0 and 1, the less corresponding transparency level  <br><hr>

# %% [markdown]
# <span style="color:blue;background-color:yellow;font-weight:bold;font-size:20px;
#              border:2px double white; padding:2px">self.play|add|wait()</span><br>
# <ol>
#     <li>self.play()</li>
#         <ol>
#             <li>direct motion</li>
#                 <ul>
#                     <li>Create(obj) -oupt frame motion is similar like draw an object</li>
#                     <li>Write(obj-text) -write </li>
#                     <li>Rotate(obj)</li>
#                     <li>Transform/ReplacementTransform(obj1,obj2)</li>
#                     <li>Chained with Animate</li>
#                     <li>Write(obj-text)</li>
#                     <li>Rotate(obj)</li>
#                     <li>---pending update--</li>
#                     <li>---pending update--</li>
#                     <li>---pending update--</li>
#                 </ul>
#             <li>chained motion</li>
#                 <ul>
#                     <li>positioning</li>
#                         <ol>
#                             <li>absolute positioning</li>
#                                 <ul>
#                                     <li>.animate.move_to([x,y,z])</li>
#                                     <li>.animate.shift(DIR*n)</li>
#                                     <li>.animate.to_corner(DIR)</li>
#                                     <li>.animate.to_edge(DIR)</li>
#                                 </ul>
#                             <li>relative positioning</li>
#                                 <ul>
#                                     <li>.animate.next_to(obj,DIR,buff=n)</li>
#                                     <li>.animate.align_to(obj,DIR)</li>
#                                     <li>VGroup(obj1,obj2).animate.arrange(DIR,buff=n)</li>
#                                 </ul>
#                             <li>dynamic|static positioning|</li>
#                                 <ul>
#                                     <li>.animate.dot.add_updater(lambda m: m.next_to(obj, DIR))<br>&emsp;&emsp;add_updater(function): Binds a custom function that recalculates the position at every frame.</li>
#                                     <li>.animate.my_object.f_always(lambda: my_object.next_to(target_object, UP)<br>&emsp;&emsp;f_always(): A convenient helper to force one function (like next_to) to run continuously.
# </li>
#                                     <li>.animate.scale(n)</li>
#                                 </ul>
#                         </ol>
#                 </ul>
#         </ol>
#     <li>self.wait()</li>
#         <ol>interpolate pause between different frames </ol>
#     <li>self.add()</li>
#         <ol>add objects to the Scene, creating a static frame , which is rendered as output in photo format</ol>
# </ol>

# %% [markdown]
# <div style="background-color:cyan;font-size:20px;
#     font-weight:bold;
#     color:darkmagenta"> Invese | negative relationship </div>In statistics, there is a negative relationship or inverse relationship between two variables<br> if higher values of one variable tend to be associated with lower values of the other.<br> A negative relationship between two variables usually implies that the correlation between them is negative, or — what is in some contexts equivalent — that the slope in a corresponding graph is negative.A negative correlation between variables is also called anticorrelation or inverse correlation.

# %% [markdown]
# <div style="background-color:amber;font-size:20px;
#     font-weight:bold;
#     color:teal">Video Demonstration Rendered Below</div>

# %%
from IPython.display import Video
Video('video/createacircle.mp4', width=400, height=280)
# Out:
# <video src="video/createacircle.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="color:red;background-color:beige">Case Designatio</div>
# <ol>
# <li>capitalized -  object </li>
# <li>lowercase  -  constant/parameter</li>
# <li>uppercase  - argument </li>
# </ol>
# <span style="border:2px double white;font-size:20px;background-color:brown;color:silver;font-weidght:bold">Tips🗒</span>
# <ul>
# <li>All <u><b><mark>animations</mark><b></u> must reside within <u>construct() method of a class derived from scene</u>.</li> <li>Other code , such as auxiliay or mathemetical functions , may reside outside the class.</li>
# </ul>
# </hr>

# %% [markdown]
# <hr><div style="font-size:20px;background-color:cyan;
#         color:darkmagenta;font-weight:bold">Recap</div><hr>
# <ul>
# <li> <b>Scene</b>:&emsp; &rarr;&emsp;animation canvas </li>
# <li> <u><b><span style="background-color:beige;color:indigo">Mobjects</span></b></u></li>
#     <ul style="list-style-type:circle;">
#         <li>Manim objects -<u><b>C</b></u>ircle <u><b>S</b></u>quare</li>
#         <li><span text-decoration-style:dashed;>Manim objects properties-color, fill_opacity--</span></li>
#     </ul>
# <li><U><mark><b>global constant<b></mark></U> : </li>
#      <ul style="list-style-type:circle;">
#         <li>colors: <u>BLUE,GREEN...</u> </li>
#         <li>directions <u>UP DOWN RIGHT...</u></li>
#     </ul>
# </ul><hr>

# %% [markdown]
# <hr><div style="font-size:20px;font-weight:bold;color:cyan;background:indigo">add. wait . play animations!</div><hr>
# <ul>
# <li>Scene.add&emsp;&rarr; adds Mobjects immediately to the Scene</li>
# <li>Scene.wait&emsp;&rarr;  add a pause </li>
# <li>Scene.play&emsp;&rarr;  plays animations </li><hr>
# <ul style="list-style-type:circle;">
#  <li>Animations can ...</li>
#       <ul style="list-style-type:square;">
#          <li>add | remove Mobjects: </li>
#                  <ul style="list-style-type:disc">
#                      <li>Create | Uncreate</li>
#                      <li>FadeIn | FadeOut</li>
#                      <li>...</li>
#                  </ul>
#          <li>change Mobjects: </li>
#                  <ul style="list-style-type:disc">
#                      <li>Transform</li>
#                      <li>...</li>
#                  </ul>
#         <li>emphasize Mobjects: </li>
#                  <ul style="list-style-type:disc">
#                      <li>Indicate | Circumscribe</li>
#                      <li>...</li>
#                  </ul>
#        </ul>
# </ul>
# <hr>
# <ul>
# <li>self.<span style="color:cyan">play</span>
#     (<span style="color:yellow;backrgound-color:white">Create</span>
#     (Mobject,<mark>run_time=n</mark>),Create(Mobject2,run_time=n2))</li>
#
# <li>self.play(DrawBorderThenFill(Mobject)</li>
# <li>self.play(Transform(Mobject1, Mobject2)</li>    <hr>
# <li>self.play(FadeOut(Mobject1) &emsp;&rarr;&ensp;The arguemnet to be passed into FadeOut parameter should be <br>
#    &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;&ensp; Mobject 1 since it was morphed in to the shape of Mobject2, Mobject2 is the transformed Mobject1</li>    <hr>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Two: Transforming a square into a circle | Code Explanation </div>
#
# %%manim -qm class TransfSqr2Cir(Scene):<br>
#     &emsp;class tsqr2cir(Scene):<br>
#     def construct(self):<br>
#         &emsp;&emsp;circle = Circle(color=RED,fill_opacity=1).shift(LEFT*2)<br>
#         &emsp;&emsp;🚫square = Square(color=WHITE,fill_opacity=1).shift(RIGHT*2) |in method 2 it can be deleted only object is needed<br><br>
#         &emsp;&emsp;square.rotate( PI / 4 )
#         <span style="border:5px double brown; background-color:yellow;color:indigo;padding:5px;font-weight:bold">
#             &rarr;&emsp;PI -constant which denotes 180$\degree \hspace{0.5cm} \frac{\pi}{4}=45\degree$<hr></span>
#         &emsp;&emsp;self.play(Create(circle,run_time=3))<br>
#         &emsp;&emsp;self.play(Create(square,run_time=3))<br>
#         &emsp;&emsp;self.wait(1)<br>
#         &emsp;&emsp;self.play(FadeIn(circle,run_time=3))<br>
#         &emsp;&emsp;self.play(FadeIn(square,run_time=3))<br>
#         &emsp;&emsp;self.wait(1)<br>
#         &emsp;&emsp;self.wait(1)<br>
#         &emsp;&emsp;self.play( <span style="color:red">Transform </span>( <mark>circle</mark>  , <u>square</u>, ))  <br>
#         &emsp;&emsp;self.play(FadeOut(square),run_time=3) <br>
#
#
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;font-size:20px;
#              border:2px double white; padding:2px">workflow</span>
# <ul>
#     <li>Method1</li>
#     <ol>
#             <li>creation of two individual object</li>
#             <li>transform obj1 to obj2:&nbsp;&nbsp; obj1 &rarr;  obj2</li>
#             <li>syntax: &emsp; &emsp; &emsp; &emsp;&emsp; &emsp;&emsp; &emsp;&emsp; &emsp;🔜 <br>
#                 &emsp;&emsp; self.play( <span style="color:red">Transform </span>( <mark>obj1</mark>  , <u>obj2</u> ) </li>
#     </ol>
#     <li>Method2 delete the instance initiation line of code later</li>
#     <ul>
#             <li>creation of <b>only</b> the object1 </li>
#             <li>transform obj1 to obj2  :&emsp;&emsp; obj1 &emsp; &rarr; &emsp; obj2</li><hr>
#             <div style="background-color:cyan;color:darkgreen;
#                         font-weight:bold;
#                 "><li>difference</li>
#             <li>&emsp;&emsp;&emsp;&emsp;  the creation of obj2 occurs simultaneously in the process of transformation:<br>
#                 &emsp;&emsp; &emsp;&emsp; thus it assume the parent class properties </li></div>
#     </ul>
# <ul>

# %%
from IPython.display import Video
Video('video/TransfSqr2Cir.mp4', width=400, height=280)
# Out:
# <video src="video/TransfSqr2Cir.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Three: Square and Circle | Code Explanation </div>
# &emsp;class sqrncir(Scene):<br>
#  &emsp;&emsp;    def construct(self):<br>
#  &emsp;&emsp; &emsp;&emsp;        circle = Circle(radius=2, color=GREEN_A,fill_opacity=0.5)<br>
#  &emsp;&emsp; &emsp;&emsp;        square = Square(side_length=4, color=RED,fill_opacity=0.5)<br><hr>
# <ul>
#     <li> <mark>⚪animate the next_to movement by chaining the next_to with obj1</mark></li>
# </ul>
#  &emsp;&emsp; &emsp;&emsp;        self.play(Create(circle),RUN_TIME=2)<br>
#  &emsp;&emsp; &emsp;&emsp;       self.play(Create(square),RUN_TIME=2)<br>
#  &emsp;&emsp; &emsp;&emsp;        self.wait(2)<br>
#  &emsp;&emsp; &emsp;&emsp;      self.play(square.animate.next_to(circle,RIGHT, buff=0.5),RUN_TIME=2)<br><hr>
# <ul>
#     <li><span style="background-color:cyan;color:indigo">
#         ⚫statically place object1 next to object2</span></li>
# </ul>
#  &emsp;&emsp; &emsp;&emsp; circle.next_to(square, RIGHT, buff=0.5)<br>
#  &emsp;&emsp; &emsp;&emsp; self.play(Create(circle),Create(square))
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;font-size:20px;
#              border:2px double white; padding:2px">workflow</span>
# <ul>
#     <li>Method1: <mark><b>animate the next_to movement</b></mark></li>
#     <ol>
#             <li>initializing two individual object</li>
#             <li>self.play(Create(obj1)) use Create to animate obj1 and obj2</li>
#             <li>self.play(obj1.animate.next_to(obj2,UP,buff=1))</li>
#     </ol>
#     <li>Method2: <span style="background-color:cyan;color:indigo;font-weight:bold">
#         statically place object1 next to object2</span></li>
#     <ol>
#             <li>creation of two individual objects</li>
#             <li>place obj1 next to obj2: statically place the object behind the scene</li>
#             <li>self.play(Create(obj1),Circle(obj2)) : when animate , the two objects are already in their respective locations</li>
#     </ol>
#     </ul>
# <ul>
# <table style="border:2px double white">
#      <th>initializing two individual object </th>
#      <th>place obj1 next to obj2: statically place the object behind the scene</th>
#     <tr>
#         <td><img src="images/sqrciranim (1).png" width="500" height="500"></td>
#         <td><img src="images/sqrciranim (2-).png" width="500" height="500" ></td>
#      </tr>
#     <tr>
#         <td>position is determined by the level of quality of the density setting</td>
#         <td></td>
#     </tr>
# </table>

# %% [markdown]
# <table style="border:2px double white;backrgound-colr:cyan">
#                   <tr style="border: 1px solid white;padding: 12px;text-align: center;">
#                         <th >syntax: object1.next_to(object2,diretion,buff)</th>
#                   </tr style="border: 1px solid white;padding: 12px;text-align: center;">
#                     <tr style="border: 1px solid white;padding: 12px;text-align: left;">
#                         <td ></td>
#                         <td >self.play(obj1.animate.next_to(obj2,dir,buff)</td>
#                         <td >directly chain the next_to movement to the animate method
#                             so it can be passed as argument in side the self.play method </td>
#                   </tr style="border: 1px solid white;padding: 12px;text-align: left;">
#                   <tr>
#                     <td width="333.333">parameter1</td>
#                     <td width="333.333">parameter2</td>
#                     <td width="333.333">parameter3</td>
#                   </tr>
#                   <tr style="border: 1px solid white;padding: 12px;text-align: left;">
#                     <td>reference point</td>
#                     <td>direction relative to the reference point</td>
#                     <td>distance|buffer relative to the reference point </td>
#                   </tr>
#                   <tr style="border: 1px solid white;padding: 12px;text-align: left;">
#                     <td>Mobject class instance</td>
#                     <td>UP  |DOWN | RIGHT | LEFT |<br><span style="color:gold">&emsp;&emsp;&emsp;<b>ORIGIN</b>&emsp;&emsp;</span><br>
#                         | DR | DL | UR | UL</td>
#                     <td>buff=n</td>
#                   </tr>
# </table>

# %%
from IPython.display import Video
Video('video/sqrncir.mp4', width=400, height=280)
# Out:
# <video src="video/sqrncir.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # 📓-2️⃣ Position | Configuration

# %% [markdown]
# <li><div style="background-color:brown;color:lightcyan;font-size:20px;
#         font-weight:bold;">using .animate syntax </div></li>    <hr>
# <li>we have aleady seen self.play( Create(obj)| &emsp; |Transform(obj1,obj2)) &emsp;
# and obj1.next_to(obj2,DIRECTION,buff=n)</li>
# <li>However, the .animation when chained with object to perform such as next_to movement ,
# it gives more control over the overall animation process<br>&emsp;&emsp;
# eg:<hr>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.next_to(obj2,UP,buff=0.5)) &rarr;using obj as reference
# </b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.set_fill(COLOR,opacity=0.5))</b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.rotate(PI/4))
# </b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.move_to([x,y,z] coordinates|<mark>exisiting obj2</mark>))<br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; obj2 will to removed , if obj1 is moved to the spot where obj2 used to be
# </b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.to_coner(UP+LEFT))
# </b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.to_edge(UP+LEFT))
# </b></div></li>
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.shift(LEFT*n)) &emsp;&rarr;unit based movement (using origin as reference)
# <li><div style="background-color:silver;color:blue"><b>&emsp;&emsp;&emsp;&emsp;self.play(obj1.animate.align_to(UP+LEFT))➤<br> use direction to determine the border -<br> the coordinates of the borders of a mobject are determined using an imaginary bounding box around it
# </b></div></li>
# </ul>
# <hr>

# %% [markdown]
# bounding box - is used for deeep machine learning :<br>boundary base can be employed to represent object thats recognizable to machine , for <br>classification , clustering ,grouping for model tranining <br>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Four: sqrnciranim animation | Code Explanation </div>
#
# &emsp;class sqrnciranim(Scene):<br>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;            circle = Circle(radius=1, color=GREEN_A,fill_opacity=0.8)<br>
# &emsp;&emsp; &emsp;&emsp;            square = Square(side_length=2, color=RED,fill_opacity=0.8)<hr>
# &emsp;&emsp; &emsp;&emsp;              self.play(Create(circle),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(Create(square),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.next_to(circle,RIGHT, buff=1.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.set_fill( color=YELLOW_A, opacity=0.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.rotate( PI/2), RUN_TIME=5)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.next_to(circle,RIGHT, buff=0.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(Transform(square, circle),RUN_TIME=2)<br>
#
#
# <hr>
# <mark><b></b>run_time :</b></mark> it specifies the duration in which the animation is compeleted
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span>
# <table style="border:1px dashed white;padding:1px">
#     <tr>
#         <th width="200">1 Create circle🔴 and <br>&emsp;square🔶</th>
#         <th width="200">2 place square Next_to circle<br>&ensp; at the right side ➡<br>&ensp;with a buffer of 1.5</th>
#         <th width="200">3 fill the square with <br>&emsp;color of green</th>
#         <th width="200">4 rotate the square ↩</th>
#         <th width="200">5 transform the square into a circle🔆</th>
#     </tr>
#     <tr>
#         <th><img src="images/sqrciranim (1).png"  width="200"></th>
#         <th><img src="images/sqrciranim (2-).png" width="200"></th>
#         <th><img src="images/sqrciranim (3-).png" width="200"></th>
#         <th><img src="images/sqrciranim (4-).png" width="200"></th>
#         <th><img src="images/sqrciranim (5-).png" width="200"></th>
#     </tr>
# </table>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Four: sqrnciranim animation | Code Explanation </div>
#
# &emsp;class sqrnciranim(Scene):<br>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;            circle = Circle(radius=1, color=GREEN_A,fill_opacity=0.8)<br>
# &emsp;&emsp; &emsp;&emsp;            square = Square(side_length=2, color=RED,fill_opacity=0.8)<hr>
# &emsp;&emsp; &emsp;&emsp;              self.play(Create(circle),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(Create(square),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.next_to(circle,RIGHT, buff=1.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.set_fill( color=YELLOW_A, opacity=0.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.rotate( PI/2), RUN_TIME=5)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(square.animate.next_to(circle,RIGHT, buff=0.5),RUN_TIME=2)<br>
# &emsp;&emsp; &emsp;&emsp;              self.play(Transform(square, circle),RUN_TIME=2)<br>
#
#
# <hr>
# <mark><b></b>run_time :</b></mark> it specifies the duration in which the animation is compeleted
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span>
# <table style="border:1px dashed white;padding:1px">
#     <tr>
#         <th width="200">1 Create circle🔴 and <br>&emsp;square🔶</th>
#         <th width="200">2 place square Next_to circle<br>&ensp; at the right side ➡<br>&ensp;with a buffer of 1.5</th>
#         <th width="200">3 fill the square with <br>&emsp;color of green</th>
#         <th width="200">4 rotate the square ↩</th>
#         <th width="200">5 transform the square into a circle🔆</th>
#     </tr>
#     <tr>
#         <th><img src="images/sqrciranim (1).png"  width="200"></th>
#         <th><img src="images/sqrciranim (2-).png" width="200"></th>
#         <th><img src="images/sqrciranim (3-).png" width="200"></th>
#         <th><img src="images/sqrciranim (4-).png" width="200"></th>
#         <th><img src="images/sqrciranim (5-).png" width="200"></th>
#     </tr>
# </table>

# %%
from IPython.display import Video
Video('video/sqrnciranim.mp4', width=400, height=280)
# Out:
# <video src="video/sqrnciranim.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <ul>
#     <li>Manim uses 3D coordinate system<br>
# &rarr;Internally points are numpy arrays</li><hr>
#     <li>Default(2D) settings: Scene frame is </li>
#         <ul style="list-style-type:circle">
#             <li>8 Munits [Manim Units] in height  4 -4 </li>
#             <li>14 + $\frac{2}{9}$ = 14.2$2_{.}^{.}$ Munits in width</li>
#             <li><b><u>Origin(0,0,0)</u></b> is at the center of the frame; it measures [-7.11 , +7.11] x [-4,4] Munit</li>
#             <li>Pixel measurements of output depend on quality settings</li>
#         </ul>
# </li>
# </ul>
# <hr>
# <ul>
# <li>RIGHT==(1, 0, 0) <span style="color:red;background-color:cyan">Right</span> </li>
# <li>sqr.shift(2*UP+4*RIGHT)</li>
# <li>dot.next_to(UP+RIGHT)</li>
# <LI>cir.move_to([-3,-2,0]) &emsp;&emsp;&emsp;&emsp;&rarr;: anchor point is the object's center</LI>
# <li>cir.align_to(rectangle,UP) &emsp;&emsp;&nbsp;&rarr;: the top egde of the rectanle is aligned with Quadratic point of a circle</LI>
# <li>cir2=cir.<span style="background-color:cyan;color:darkmagenta">copy().set_color(X)</span>&emsp;&nbsp;&nbsp;&nbsp;&rarr;: <span style="background-color:cyan;color:darkmagenta">chain method-</span> directly call method upon the copied object </li>
# </ul>

# %%
# %%HTML
# <style> table{float:center;background-color:black;color:cyan;border-spacing: 0px;border: 0px solid black}
#         th, td {text-align:left;border: 1px solid black; padding: 20px;}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# Out:
# <style> table{float:center;background-color:black;color:cyan;border-spacing: 0px;border: 0px solid black}
#         th, td {text-align:left;border: 1px solid black; padding: 20px;}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">

# %% [markdown]
# <div style="background-color:silver;font-size:20px;
#     font-weight:bold;
#     color:cyan">Example Five: flipshiftsquare animation | Code Explanation </div>
# &emsp;class FlipShiftSquare(Scene):<br>
#    &emsp;&emsp;  def construct(self):<br>
#    &emsp;&emsp;   &emsp;&emsp;          ax=Axes(x_range=[-5, 5], y_range=[-5, 5], axis_config={"color": GREY})<br>
#    &emsp;&emsp;    &emsp;&emsp;         plane    = NumberPlane()<br>
#    &emsp;&emsp;    &emsp;&emsp;         self.add(ax,plane)<br>
#    &emsp;&emsp;      &emsp;&emsp;       right_square = Square(side_length=1, color=RED, fill_opacity=0.5).shift(RIGHT * 2)<br>
#    &emsp;&emsp;      &emsp;&emsp;       self.play(Create(left_square), Create(right_square))<hr>
#    &emsp;&emsp;     &emsp;&emsp;        # Flip the square horizontally<hr>
#    &emsp;&emsp;     &emsp;&emsp;         self.play(left_square.animate.flip(axis=UP))<br>
#    &emsp;&emsp;     &emsp;&emsp;         self.play(right_square.animate.flip(axis=DOWN))<br>
#    &emsp;&emsp;     &emsp;&emsp;         self.play(left_square.animate.rotate(PI / 4))<br>
#    &emsp;&emsp;     &emsp;&emsp; self.play(right_square.animate.rotate(PI / 4))<hr>
#    &emsp;&emsp;     &emsp;&emsp;        # Shift the square to the right<hr>
#    &emsp;&emsp;     &emsp;&emsp;        self.play(left_square.animate.shift(UP * 2))<br>
#    &emsp;&emsp;     &emsp;&emsp;        self.play(right_square.animate.shift(DOWN * 2))<br>
#    &emsp;&emsp;     &emsp;&emsp;        arr=Arrow(start=LEFT * 2, end=RIGHT * 2, color=WHITE)<br>
#    &emsp;&emsp;     &emsp;&emsp;        self.play(Create(arr))<br>
#    &emsp;&emsp;     &emsp;&emsp;        self.play(arr.animate.next_to(left_square, ORIGIN, buff=0))<br>
#    &emsp;&emsp;     &emsp;&emsp;        self.play(FadeOut(left_square), FadeOut(right_square)<br>
#
#
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;font-weight:bold;">
#    &emsp;&emsp;     &emsp;&emsp;0.&emsp;&emsp;self.add(ax,number_plane<br>
#    &emsp;&emsp;     &emsp;&emsp;1.&emsp;&emsp;create left and right square object<br>
#    &emsp;&emsp;     &emsp;&emsp;2 &emsp;&emsp;flip squares <br>
#    &emsp;&emsp;     &emsp;&emsp;3 &emsp;&emsp;shift squares<br>
#    &emsp;&emsp;     &emsp;&emsp;4 &emsp;&emsp;add arrow object<br>
#    &emsp;&emsp;     &emsp;&emsp;5 &emsp;&emsp;place arrow next to the left square<br>
#    &emsp;&emsp;     &emsp;&emsp;6 &emsp;&emsp;fade out squares<br>     </div>
# <hr>

# %%
from IPython.display import Video
Video('video/FlipShiftSquare.mp4', width=400, height=280)
# Out:
# <video src="video/FlipShiftSquare.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="border: 1px solid gold; padding: 1px; font-size:25px;font-weight:bold;color:black;
#     display: block;background-color:beige">
#   Rotate(o,PI) vs o.<u>animate.rotate</u>(PI):
#     </div>
# <ul>
#     <li>Roate(o,PI)<br>&emsp;&emsp;The objest won't change in size during roation</li>
#     <li>o.animate.rotate(PI)<br>&emsp;&emsp;The object will first
#         <span style="background-color:yellow;color:red">shrink
#         </span> in size and then expand during revolution</li>
#     <li>self.play(Rotate(obj1,angle=PI/4),obj2.animate.rotate(PI/4)
#         <div style="background-color:cyan;color:black;font-weight:bold;">
#         &emsp;&emsp;$\pi$ pi is consider a number(180) ,
#         thus not need to enclose it in double quotaion marks<br>&emsp;&emsp;
#         IF WE place two rotation within a single self.play() method,
#         then they will synchronize and there won't be any shrinking or expanding
#         </div> </li>
# </ul><hr>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Six: RotVsAniRot Difference | Code Explanation </div>
# &emsp;class RotVsAniRot(Scene):<br>
#    &emsp;&emsp;     def construct(self):<br>
#      &emsp;&emsp;   &emsp;&emsp;           left_square = Square(color=RED, fill_opacity=0.5).shift(LEFT*2)<br>
#      &emsp;&emsp;   &emsp;&emsp;           right_square = Square(color=BLUE, fill_opacity=0.5).shift(RIGHT*2)<br>
#      &emsp;&emsp;   &emsp;&emsp;           self.play(Create(left_square))<br>
#      &emsp;&emsp;   &emsp;&emsp;           self.play(Create(right_square))<hr>
#      &emsp;&emsp;   &emsp;&emsp;           self.play(Rotate(left_square, angle=PI/4),
#      right_square.animate.rotate(-PI/4),run_time=8)<hr>
#      &emsp;&emsp;   &emsp;&emsp;           self.play(Rotate(left_square, angle=PI/4,run_time=2))<br>
#      &emsp;&emsp;   &emsp;&emsp;           self.play(right_square.animate.rotate(-PI/4),run_time=2)<br>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">Difference</span><hr>
#             <div style="background-color:cyan;color:black;font-weight:bold;"><hr>
#    &emsp;&emsp;0.self.play(Rotate(object1,angle=PI)<br>
#                  &emsp;&emsp;     &emsp;&emsp; &emsp;&emsp;Regular Rotation<br>
#    &emsp;&emsp;1.self.play(objec1.animate.rotate(PI)<br>
#                  &emsp;&emsp;     &emsp;&emsp; &emsp;&emsp;object will shrink and then expand<hr>
#    &emsp;&emsp;2 self.play(Rotate(object1, angle=PI/4),
#      object2.animate.rotate(-PI/4)) <br>
#                  &emsp;&emsp;     &emsp;&emsp; &emsp;&emsp;two objects will be synchronized so that no shrinkage or expansion will take place    <hr>
# </div>

# %%
from IPython.display import Video
Video('video/RotVsAniRot.mp4', width=400, height=280)
# Out:
# <video src="video/RotVsAniRot.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Seven: transfrepl animation | Code Explanation </div>
# &emsp;class transfrepl(Scene):<br>
#    &emsp;&emsp;      def construct(self): <br>
#      &emsp;&emsp;   &emsp;&emsp;          a=Tex("a",color=RED,font_size=100).shift(LEFT)<br>
#       &emsp;&emsp;   &emsp;&emsp;         b=Tex("b",color=GREEN,font_size=100).shift(RIGHT)<br>
#      &emsp;&emsp;   &emsp;&emsp;          c=Tex("c",color=BLUE,font_size=100).shift(UP)<hr>
#     &emsp;&emsp;   &emsp;&emsp;           self.play(Write(a),Write(b),Write(c))<br>
#       &emsp;&emsp;   &emsp;&emsp;         self.play(<mark>Transform(a &#127824;,b &#127818;))</mark><br>
#      &emsp;&emsp;   &emsp;&emsp;          self.play(FadeOut(a))      <br>
#      &emsp;&emsp;   &emsp;&emsp;          arrow=Arrow(start=LEFT,end=RIGHT,color=YELLOW).shift(DOWN)  <br>
#      &emsp;&emsp;   &emsp;&emsp;          self.play(arrow.animate.next_to(b,LEFT,buff=0))<br>
#     &emsp;&emsp;   &emsp;&emsp;           self.play(<u><b>ReplacementTransform( a &#127818; , c &#127826;))</b></u> <br>
#       &emsp;&emsp;   &emsp;&emsp;         self.play(FadeOut(c))<br>
# <table style="border:1px dashed white;padding:1px">
#     <tr>
#         <th width="200">1 create a&#127824; b&#127818; c&#127826; </th>
#         <th width="200">2 a&#127824; transformed into b&#127818;</th>
#         <th width="200">3 arrow indicates a&#127824; </th>
#         <th width="200">4 a&#127818; replaced by c&#127826;</th>
#         <th width="200">5 fadeout c &#127826;</th>
#     </tr>
#     <tr>
#         <th><img src="images/transfrepl1.png"  width="200"></th>
#         <th><img src="images/transfrepl2.png" width="200"></th>
#         <th><img src="images/transfrepl3.png" width="200"></th>
#         <th><img src="images/transfrepl4.png" width="200"></th>
#         <th><img src="images/transfrepl5.png" width="200"></th>
#     </tr>
# </table>

# %%
from IPython.display import Video
Video('video/transfrepl.mp4', width=400, height=280)
# Out:
# <video src="video/transfrepl.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:gold;color:darkmagenta;font-size:20px;font-weight:bold;">ReplacementTransform vs Transform | eg: sqr obj1 and cir obj2</div>
# <div style="background-color:lightgreen;color:darkmagenta;font-size:12px;
#         font-weight:bold;">
# <ol>
#     <li>Transform(obj1 , obj2 )</li>
#      <ul>
#          <li>although after the transformation, the transformed object(obj1) assumes the shape and appeance <br>of the second object, however, its still the first object.<br> &rarr;&emsp;Therefore, the syntax should be <br>self.play(FadeOut(obj1) on the contrary, if obj2 is passed in , it won't fade away, as the method is called upon the object thats been rendered invisible.<br><u>Analogy</u>, the innocent person has been posessed by demon, although he appears to be the person, it 's actually a monster that assumes the form of a human</li>
#      </ul>
#     <li>ReplacementTransform(obj1 , obj2 )</li>
#      <ul>
#          <li>after rendering, the obj1 is replaced by obj2, thus whatever the method should be called upon object2 directly <br>&rarr;&emsp;Thus, the syntax should be self.play(FadeOut(obj2)<br><u>Analogy</u> : catapillar morphed into a butterfly, the catapillar is vanished .</li>
#      </ul>
# </ol></div>

# %% [markdown]
# <table>
#     <th width="333.3333">o.move_to( [ ]   )</th>
#     <th width="333.3333">o.shift(  dirs   )</th>
#     <th width="333.3333">o.next_to(o,dir  ) </th>
#     <tr>
#         <td> &emsp;  &emsp;&emsp;   x , y , z &rlarr;</td>
#         <td> n*dir1+n*dir2   &emsp; </td>
#         <td> RIGHT</td>
#     </tr>
#     <tr>
#         <td><img src="images/move_to.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/shift.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/next_to.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
#     <th width="333.3333">o.align_to(o     )</th>
#     <th width="333.3333">o.align_to(o,dir )</th>
#     <th width="333.3333">o.align_to(o,dir1s)</th>
#     <tr>
#         <td> center</td>
#         <td> LEFT</td>
#         <td> UP+RIGT</td>
#     </tr>
#     <tr>
#         <td><img src="images/align_to.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/align_to1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/align_to2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>

# %% [markdown]
# <table text-align:left>
#     <th width="333.333">9 critical points - <br>consider it as bounding box</th>
#     <th width="333.333">Code </th>
#     <th width="333.333">Code Explanation</th>
#     <tr style="background-color:cyan;color:darkmagenta;font-weight:bold">
#         <td ><img src="images/9cp.png" alt="1.jpg" width="333.333" height="333.333"> </td>
#         <td >for d in <br>&emsp;[(0,0,0),UP,UR,RIGHT,DR,DOWN,DL,LEFT,UL]:<hr><br><br><hr>
#             self.add(<br>&emsp;Cross(scale_factor=<br>
#             &emsp;0.1).move_to(c.get_critical_point(d)))</td>
#         <td >(0,0,0) original + 8 points </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <th width="333.333"></th>
#     <th width="333.333"></th>
#     <th width="333.333"></th>
#     <tr>
#         <td><img src="images/move_to1.png" alt="1.jpg" width="350" height="350"></td>
#         <td style="color:beige">o.move_to( [x,y,z] , alighned_edge=dir)<hr><br><br><hr>if the alignment method parameter is not not specified,<br> then only referring to the center point for alighmnet </td>
#         <td>critical point left is<br> illustrated in the<br>
#         next_to method that moves the rectangle to the left side of the circle</td>
# </tr>
# </table>

# %% [markdown]
# <table >
#      <th>-qk 4k </th>
#      <th>-ql 480</th>
#     <tr>
#         <td><img src="images/qk.png" width="500" height="500"></td>
#         <td><img src="images/ql.png" width="500" height="500" ></td>
#      </tr>
#     <tr>
#         <td>position is determined by the level of quality of the density setting</td>
#         <td></td>
#     </tr>
# </table>

# %% [markdown]
# Grouping
# <ul>
#     <li>vectorized object -most of the Mobjects</li>
#         <ol>
#             <li>Method : VGroup(ob1,ob2,ob3...)</li>
#             <li>Purpose: To manipulate them as a single object</li>
#         </ol>
#     <li><u>Nonvectorized object</u>  imported pictures </li>
#         <ol>
#             <li>Method : <span style="color:red">doesnt support VGROUP</span></li>
#             <li>Purpose: ---</li>
#         </ol>
# </ul>

# %% [markdown]
# <table >
#      <th>GROUP.to_edge(LEFT) </th>
#      <th>GROUP.to_edge(RIGHT) </th>
#     <tr>
#         <td><img src="images/g1.png" width="500" height="500"></td>
#         <td><img src="images/g2.png" width="500" height="500" ></td>
#      </tr>
#     <tr>
#         <td><div style="color:cyan;background-color:black"><hr>class groupingR(Scene):<BR>
#         &emsp;def construct(self):<br>
#         &emsp; &emsp;red_dot  =Dot(color=RED)<br>
#         &emsp; &emsp;green_dot=Dot(color=GREEN).next_to(red_dot, RIGHT)<br>
#         &emsp; &emsp;blue_dot =Dot(color=BLUE).next_to(red_dot,UP)<br>
#         &emsp; &emsp;dot_group=VGroup(red_dot,green_dot,blue_dot)<br>
#         &emsp; &emsp;dot_group.to_edge(RIGHT)<br>
#         &emsp; &emsp;self.add(dot_group)<hr></div></td>
#         <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#         &emsp;def construct(self):<br>
#         &emsp; &emsp;obj  =Mo(parameter=ARGUMENT)<br>
#         &emsp; &emsp;obj2  =Mo(parameter=ARGUMENT).next_to(obj1, DIR)<br>
#         &emsp; &emsp;obj3  =Mo(parameter=ARGUMENT).next_to(OBJ2, DIR)<br>
#         &emsp; &emsp;obj_group=VGroup(obj1,obj2,obj3)<br>
#         &emsp; &emsp;obj_group.to_edge(RIGHT)<br>
#         &emsp; &emsp;self.add(obj_group)<hr></div></td>
#         <td></td>
#     </tr>
# </table>

# %% [markdown]
# <table >
#      <th>GROUP Manipulation </th>
#     <tr>
#         <td><img src="images/g3.png" width="1000" height="400"></td>
#      </tr>
#      <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#              &emsp;ddef construct(self):<hr>
#          <ul>
#                 <li>&emsp; &emsp;red_dot  =Dot(color=RED)</li>
#                 <li>&emsp; &emsp;green_dot=Dot(color=GREEN).next_to(red_dot, RIGHT)</li>
#                 <li>&emsp; &emsp;blue_dot =Dot(color=BLUE).next_to(red_dot,UP)</li>
#          </ul>
#                 &emsp; &emsp;dot_group=VGroup(red_dot,green_dot,blue_dot)
#                 &emsp; &emsp;dot_group.to_edge(RIGHT)<hr>
#                 &emsp; &emsp;dot_gr1  =dot_group.copy().set_color(WHITE)
#                 &emsp; &emsp;dot_gr1.move_to([0,0,0])<hr>
#                 &emsp; &emsp;dot_gr2 =dot_group.copy()
#                 &emsp; &emsp;dot_gr2.to_edge(LEFT)<hr>
#                 &emsp; &emsp;dot_gr3 =dot_group.copy()
#                 &emsp; &emsp;dot_gr3.shift(3*UP+6.35*LEFT)<hr>
#                 &emsp; &emsp;dot_gr4 =dot_group.copy()
#                 &emsp; &emsp;dot_gr4.shift(3*DOWN+6.35*LEFT)<hr>
#                 &emsp; &emsp;self.add(dot_group,dot_gr1,dot_gr2,dot_gr3,dot_gr4)</div>
#              </td>
# </table>

# %% [markdown]
# VGroup only takes unpacked list of objects separated by comma <br>
# Therefore, if a for loop that contains a list of objects , <br>
# <span style="background-color:cyan;color:crimson"><u><b>it must be unpacked first using asterisk</b></u></span>
# <br>before being passed in as argument<br><hr>
# After assign the VGroup with a variable , then arrange method can be called upon that variable by specifying diretcions
# <br>Sytax <hr>
# <ul>
#         <li>regular individual objects<br>&emsp;variable=VGroup( obj1, obj2, obj3 ...)</li>
#         <li>for loop object list <br>&emsp;variable=VGroup( <span style="background-color:cyan;color:crimson"><u>*</u></span>
#         [ Moclass( parameter=ARGUMENT ) for in range( n )])</li>
# </ul><hr>

# %% [markdown]
# <table >
#      <th>GROUP Manipulation </th>
#     <tr>
#         <td><img src="images/arg.png" width="1000" height="400"></td>
#      </tr>
#      <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#              &emsp;ddef construct(self):<hr>
#                 &emsp; &emsp;sqr =VGroup( *[Square(side_length=2.5, color=BLUE,   fill_opacity=0.6) for _ in range(3)])
#                 &emsp; &emsp;sqr.arrange(UP   )<br>
#                 &emsp; &emsp;sqr1=VGroup( *[Square(side_length=2.5, color=YELLOW, fill_opacity=0.6) for _ in range(5)])
#                 &emsp; &emsp;sqr1.arrange(LEFT)<hr>
#                 &emsp; &emsp;self.add(dot_group,dot_gr1,dot_gr2,dot_gr3,dot_gr4)</div>
#              </td>
# </table>

# %% [markdown]
# <table >
#      <th>o.arrange(DIRECTION,buff=0)</th>
#      <th>o.arrange(DIRECTION,buff=<span style="color:red">2</span>)</th>
#     <tr>
#         <td><img src="images/b0.png" width="500" height="500"></td>
#         <td><img src="images/b2.png" width="500" height="500" ></td>
#      </tr>
#     <tr>
#         <td><div style="color:cyan;background-color:black"><hr>class groupingR(Scene):<BR>
#         &emsp;def construct(self):<br>sq=VGroup(*[Square(side_length=0.6,color=BLUE,fill_opacity=0.6) for _ in range(3)])
#         <br>sq.arrange(UP, buff=0)
#         s1=VGroup(*[Square(side_length=0.6,color=YELLOW,fill_opacity=0.6) for _ in range(5)])
#         <br>s1.arrange(LEFT, buff=0)<hr></div></td>
#         <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#         &emsp;def construct(self):<br>sq=VGroup(*[Square(side_length=0.6,color=BLUE,fill_opacity=0.6) for _ in range(3)])
#         <br>sq.arrange(UP, buff=2)
#         s1=VGroup(*[Square(side_length=0.6,color=YELLOW,fill_opacity=0.6) for _ in range(5)])
#         <br>s1.arrange(LEFT, buff=2)<hr></div></td>
#         <td></td>
#     </tr>
# </table>

# %% [markdown]
# <table >
#      <th>GROUP Manipulation </th>
#     <tr>
#         <td><img src="images/star.png" width="1000" height="400"></td>
#      </tr>
#      <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#              &emsp;ddef construct(self):<hr>
#                     <li>&emsp;&emsp;&emsp;stars=VGroup(* [Star(color=RED , fill_opacity=0.1).scale(0.1) for _ in range(20)])</li>
#                     <li>&emsp;&emsp;&emsp;stars.arrange(UP, buff=0.5)</li><hr>
#                     <li>&emsp;&emsp;&emsp;stars1=VGroup(* [Star(color=WHITE , fill_opacity=0.1).scale(0.1) for _ in range(20)])</li>
#                     <li>&emsp;&emsp;&emsp;stars1.arrange(RIGHT, buff=0.5)</li><hr>
#                     <li>&emsp;&emsp;&emsp;stars2=VGroup(* [Star(color=TEAL , fill_opacity=0.1).scale(0.1) for _ in range(20)])</li>
#                     <li>&emsp;&emsp;&emsp;stars2.arrange(DR, buff=0.5)</li><hr>
#                     <li>&emsp;&emsp;&emsp;stars3=VGroup(* [Star(color=ORANGE , fill_opacity=0.1).scale(0.1) for _ in range(20)])</li>
#                     <li>&emsp;&emsp;&emsp;stars3.arrange(DL, buff=0.5)</li><hr>
#                     <li>self.add(stars,stars1,stars2,stars3)</li><hr>
#              </td>
# </table>

# %% [markdown]
# <table >
#      <th>GROUP Manipulation </th>
#     <tr>
#         <td><img src="images/starcolrow.png" width="1000" height="400"></td>
#      </tr>
#      <td><div style="color:yellow;background-color:black"><hr>class x (Scene):<BR>
#              &emsp;ddef construct(self):<hr>
#                     <li>&emsp;&emsp;&emsp;stars=VGroup(* [Star(color=RED , fill_opacity=0.1).scale(0.1) for _ in range(20)])</li>
#                     <li>&emsp;&emsp;&emsp;stars.arrange_in_grid( 4, 5,buff=0.5)</li><hr>
#                     <li>self.add(stars,stars1,stars2,stars3)</li><hr>
#              </td>
# </table>

# %% [markdown]
# <div style="background-color:cyan;color:darkmagenta;font-size:20px;font-weight:bold">
#     Configuration &rarr;&emsp;Manim Config Module</div><hr>
# <ol>
#    <li>Idea  : Single Source of Truth for "global" settings</li>
#    <li>Documentation and Tutorial</li>
#    <li>Settings can be changed in either of the following files</li>
#    <ul>
#            <li> .py&nbsp;&nbsp;file</li>
#            <li> .cfg file</li>
#    </ul>
#    <li>Local config generation:<span style="color:darkmagenta;background-color:cyan;font-size:20px;font-weight:bold">
#        &emsp;manim cfg write -1 cwd&emsp;</span>
#        &rarr;generate a file in your local directory </li>
# </ol>    <hr>
# <ul>
#    <li>Three directories to change settings</li>
#    <ol>
#            <li>Manim checks the current directory to see whether there's a config file:
#                ❗Highest priority</li>
#            <li>.cfg file</li>
#            <li> global configuration&nbsp;&nbsp;❌&emsp;should never be altered</li>
#    </ol>
# </ul>

# %% [markdown]
# <div style="background-color:darkmagenta;color:white;font-size:20px;font-weight:bold">Configuration</div><hr>
# <div style="background-color:white;color:red;font-size:10px;font-weight:bold">Syntax<br>&emsp;&emsp;config.attribute=ARGUMENT
#     &emsp;
#     |(properties are linked using underscore instead of hyphen in HTML)|
# </div><hr>
# <ul>
#     <li>background_color=WHITE</li>
#     <li>frame</li>
#        <ol>
#             <li>frame_height=9</li>
#             <li>frame_width=16</li>
#        </ol>
#     <li>resolution</li>
#        <ol>
#             <li>pixel_height</li>
#             <li>pixel_width</li>
#        </ol>
# </ul><hr>
# <ul>
#     <li>Text.set_default()</li>
#       <ol>
#         <li>font_size=20px</li>
#         <li>color=RED</li>
#         <li>background_color=BLUE</li>
#         <li>font_weight=BOLD</li>
#       </ol>
# </ul>

# %% [markdown]
# # 📓-3️⃣ Homepage | Output

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Eight: continuousmotion animation | Code Explanation </div>
# &emsp;class continuousmotion(Scene):<br>
#    &emsp;&emsp;        def construct(self):<br>
#     &emsp;&emsp;   &emsp;&emsp;         func=lambda pos: np.sin(pos[0] /2 ) *UR + np.cos(pos[1] /2 ) * LEFT   <br>
#     &emsp;&emsp;   &emsp;&emsp;          stream_lines=StreamLines(func,  stroke_width=1.5 , max_anchors_per_line=30)  <br>
#     &emsp;&emsp;   &emsp;&emsp;          self.add(stream_lines)<br>
#     &emsp;&emsp;   &emsp;&emsp;          stream_lines.start_animation(warm_up=False , flow_speed=0.5, run_time=90)<br>
#     &emsp;&emsp;   &emsp;&emsp;          self.wait(stream_lines.virtual_time / stream_lines.flow_speed + 1)
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;">
#   <span style="color:black;font-size:10px"> &emsp;&emsp;     &emsp;&emsp;0.&emsp;&emsp;StreamLines represent the flow of a VectorField using the trace of moving agents.<br>
# Vector fields are always based on a function defining the vector at every position.<br>The values of this functions is displayed by moving many agents along the vector field and showing their trace.<hr>
#    &emsp;&emsp;     &emsp;&emsp;1.&emsp;&emsp;func (Callable[[np.ndarray], np.ndarray]) – The function defining the rate of change at every position of the vector field.<br>
#    &emsp;&emsp;     &emsp;&emsp;2. &emsp;&emsp;np.sin(np.linspace(0,1,10)) <hr>
#                 array<br>&emsp;&emsp;&emsp;&emsp;  ([0.        , 0.11088263, 0.22039774, 0.3271947 ,<br>&emsp;&emsp;&emsp;&emsp;   0.42995636,
#        0.52741539, 0.6183698 , 0.70169788, <br>&emsp;&emsp;&emsp;&emsp;  0.77637192, 0.84147098])
#    &emsp;&emsp;    <br> &emsp;&emsp;&emsp;&emsp;  pos=np.array((np.sin(np.linspace(0,1,10)),np.cos(np.linspace(0,1,10))))>   <hr> &emsp;&emsp;     &emsp;&emsp;3. &emsp;&emsp;plt.scatter(y=np.sin(pos[0]),x=np.cos(pos[1]),marker="*")</span><br>             </div>
# <hr>

# %%
from IPython.display import Video
Video('video/ContinuousMotion.mp4', width=400, height=280)
# Out:
# <video src="video/ContinuousMotion.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Nine: Latex animation | Code Explanation </div>
# &emsp;class Latex(Scene):<br>
#  &emsp;&emsp;     def construct(self):<br>
#      &emsp;&emsp;   &emsp;&emsp;        title=Text("Singer Wan's Practice on Latex",color=PURE_GREEN).scale(0.75)<br>
#  &emsp;&emsp;   &emsp;&emsp;          basel=MathTex(r"\sum_{n=1}^\infty \frac{1}{n^2}=\frac{\pi^{2}}{6}",color=LOGO_WHITE)<br>
#      &emsp;&emsp;   &emsp;&emsp;        title.next_to(basel,UP,buff=1)<br>
#     &emsp;&emsp;   &emsp;&emsp;         self.play(Write(title),Write(basel),run_time=10) <br>
#     &emsp;&emsp;   &emsp;&emsp;         self.play(FadeOut(title),FadeOut(basel))<br>
#
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;">
#   <span style="color:black;font-size:12px;
#       font-weight:bold;"> &emsp;&emsp;     &emsp;&emsp;self.play() 101 animation must be passed in as arguments<br>
#       such as Write, FadeIn , FadeOut ,Rotate/Transform/ReplacementTransform<br> obj.animate.shift/next_to/move_to/rotate()<br>
#  &emsp;&emsp;     &emsp;&emsp; syntax<br> variable=MathTex(r"latex format")
# <hr>

# %%
from IPython.display import Video
Video('video/Latex.mp4', width=400, height=280)
# Out:
# <video src="video/Latex.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:gold;color:darkmagenta;font-size:20px;font-weight:bold;">VGroup(o1,o2).arrange(DIR) : v|h</div>
# <div style="background-color:lightgreen;color:darkmagenta;font-size:12px;
#         font-weight:bold;">
# <ol>
#     <li>VGroup syntax</li>
#      <ul>
#          <li>VGroup(obj1, <mark>obj2</mark>).arrange(DOWN|UP/RIGHT|LEFT))<br>
#          the object at the <mark>last postion</mark> will take the direction argument </li>
#      </ul>
#     <li>VGroup as <span style="background-color:red"><u>verticalgroup</u></span></li>
#      <ul>
#          <li>the direction argument must be either <span style="background-color:red">DOWN or UP</span></li>
#      </ul>
#     <li>VGroup as <span style="background-color:cyan">horizontalgroup</span></li>
#      <ul>
#          <li>the direction argument must be either <span style="background-color:cyan">LEFT or RIGHT</span></li>
#      </ul>
# </ol></div>

# %% [markdown]
# <div style="color:gold;background-color:maroon;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">LaggedStart</div>
# <ul>
#     <li>syntax</li>
#         <ul>
#             <li>self.play(LaggedStart( * FadeOut( obj ,shift=DOWN) for obj in List) </li>
#         </ul>
#     <li>parameters</li>
#         <ol>
#             <li>animation_class (type[Animation]) – <br>&emsp;&emsp;Animation to apply to mobject. </li>
#             <li>mobject (Mobject) –<br>&emsp;&emsp; Mobject whose submobjects the animation, <br>&emsp;&emsp; and optionally the function, are to be applied.</li>
#             <li>arg_creator (Callable[[Mobject], Iterable[Any]] | None) <br>&emsp;&emsp;– Function which will be applied to Mobject. <br>&emsp;&emsp; </li>
#             <li>run_time (float) –
# <br>&emsp;&emsp; The duration of the animation in seconds.</li>
#             <li>lag_ratio (float) ––
# <br>&emsp;&emsp;<mark><b>Defines the delay after which the animation is applied to submobjects.</mark></b><br>&emsp;&emsp;A lag_ratio of n.nn means the next animation will play <br>&emsp;&emsp;when nnn% of the current animation has played. <br>&emsp;&emsp;Defaults to 0.05, meaning that the next animation will begin <br>&emsp;&emsp;when 5% of the current animation has played.
# <br>&emsp;&emsp;This does not influence the total runtime of the animation.<br>&emsp;&emsp;Instead the runtime of individual animations is adjusted so that<br>&emsp;&emsp;the complete animation has the defined run time.</li>
#         </ol>
#     <li>purpose</li>
#         <ul>
#             <li>Plays a series of Animation while mapping a function to submobjects</li>
#         </ul>
# </ul>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Ten: GridWarppage animation | Code Explanation </div>
# &emsp;class OpeningManim(Scene):  <br>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;title=Text("Singer Wan's Practice on Latex",color=PURE_GREEN).scale(0.75)<br>
# &emsp;&emsp; &emsp;&emsp; basel=MathTex(r"\sum_{n=1}^\infty \frac{1}{n^2}=\frac{\pi^{2}}{6}")<br>
# &emsp;&emsp; &emsp;&emsp;        VGroup(title,basel).arrange(DOWN)  <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(  Write(title),<br>
# &emsp;&emsp; &emsp;&emsp;        FadeIn(basel,shift=DOWN),run_time=10) <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(FadeOut(title),FadeOut(basel)<br>
# &emsp;&emsp; &emsp;&emsp;        transform_title=Tex("That was a transform")<br>
# &emsp;&emsp; &emsp;&emsp;        transform_title.to_corner(UP+LEFT)<br>
# &emsp;&emsp; &emsp;&emsp;        self.play(  Transform(title,transform_title),<br>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;
#                    LaggedStart(*(FadeOut(obj, shift=DOWN) for obj in basel)))<hr>
#
# &emsp;&emsp; &emsp;&emsp;        grid=NumberPlane()<br>
# &emsp;&emsp; &emsp;&emsp;        grid_title=Tex("This is a grid",font_size=72,color=PURE_BLUE)<br>
# &emsp;&emsp; &emsp;&emsp;        grid_title.move_to(transform_title) <br>
# &emsp;&emsp; &emsp;&emsp;        self.add(grid,grid_title) <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(  FadeOut(title), FadeIn(grid_title, shift=UP),<br>
# &emsp;&emsp; &emsp;&emsp;                    Create(grid, run_time=3 ,lag_ratio=0.1))<br>
# &emsp;&emsp; &emsp;&emsp;        grid_transform_title= Tex(
#   r"This was a non-linear function \\ applied to the grid ")<br>
# &emsp;&emsp; &emsp;&emsp;        grid_transform_title.move_to(grid_title,UL)<br>
# &emsp;&emsp; &emsp;&emsp;        grid.prepare_for_nonlinear_transform()
# <div style="background-color:maroon"><b>&emsp;&emsp; &emsp;&emsp; self.play(grid.animate.apply_function(<br>
# &emsp;&emsp; &emsp;&emsp;&emsp;&emsp;lambda p: p + np.array([     np.sin(p[1]),                                                                  np.sin(p[0]),
#                                                                             0             ])),run_time=3)</b></div>
# &emsp;&emsp; &emsp;&emsp;        self.play(Transform(grid_title, grid_transform_title))

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>&emsp;&emsp; &emsp;&emsp; obj1.move_to(obj2)<br>&emsp;&emsp; &emsp;&emsp; &emsp;instead of x, y, z coordinates - obj1 will occupied the position obj2 used to be</b></div>
# <div style="background-color:maroon"><b>&emsp;&emsp; &emsp;&emsp; self.play(grid.animate.apply_function(<br>
# &emsp;&emsp; &emsp;&emsp;&emsp;&emsp;lambda p: p + np.array([     np.sin(p[1]),                                                                  np.sin(p[0]),
#                                                                             0             ])),run_time=3)</b><br>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;--</div>

# %%
from IPython.display import Video
Video('video/gridwarp.mp4', width=400, height=280)
# Out:
# <video src="video/gridwarp.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Eleven: Union animation | Code Explanation </div>
# &emsp;class Union(Scene):  <br>
#
# &emsp;&emsp;     def construct(self):  <br>
# &emsp;&emsp; &emsp;&emsp;         square=Square(color=RED_A,  fill_opacity=1).move_to([-2,0,0])   <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeIn(square),run_time=2)  <br>
# &emsp;&emsp; &emsp;&emsp;           circle=Circle(color=BLUE_D,fill_opacity=1).move_to([-1.3,0.7,0])  <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeIn(circle),run_time=2) <br>
# &emsp;&emsp; &emsp;&emsp;           un=Union(square,circle).move_to([1.5,0.3,0])<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeIn(un),run_time=2)<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(un.animate.set_fill(color=LOGO_WHITE,opacity=0.5),run_time=3)<br>
# &emsp;&emsp; &emsp;&emsp;           text=Tex("Singer Wan's rendering of Union",color=PURE_GREEN).shift(UP*3)<br>
# &emsp;&emsp; &emsp;&emsp;           self.add(square,circle,un)<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Write(text),color=PURE_GREEN,run_time=6) <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeOut(square),FadeOut(circle),FadeOut(text))<br>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>&emsp;&emsp;&emsp;&emsp;obj1.move_to([x,y,z]) <br>&emsp;&emsp;&emsp;&emsp;obj2.move_to([x,y,z]) </b></div>
# <div style="background-color:maroon;color:white"><b>&emsp;&emsp; &emsp;&emsp; variable=Union(obj1,obj2).move_to([x,y,z])<br>
# &emsp;&emsp; &emsp;&emsp;&emsp;&emsp;step1 create overlapping objs     </b><br>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;step2 use Union to combine those overlapping objects</div>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;keyfunction1 -move_to([]) | Union

# %%
from IPython.display import Video
Video('video/unionobj.mp4', width=400, height=280)
# Out:
# <video src="video/unionobj.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## &rarr;eg 12-warpsquare
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Twelve: Warp Square animation | Code Explanation </div>
# &emsp;class warpsquare(Scene):  <br>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp;&emsp;&emsp;        square=Square()<br>
# &emsp;&emsp;&emsp;&emsp;        self.play<span style="color:red;background-color:cyan">(</span> ApplyPointwiseFunction <br>&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;
# <span style="color:yellow;background-color:red">(</span> lambda point:complex_to_R3 ▪( np.exp🔹( R3_to_complex<b>(</b> point <b>) </b>▪)🔹)<br>&emsp;&emsp;&emsp;&emsp;  &emsp;&emsp;&emsp;&emsp;  square,     <br>&emsp;&emsp;&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;   run_time=5,<span style="color:yellow;background-color:red">)</span>&emsp;<span style="color:red;background-color:cyan">)</span>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">workflow</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>&emsp;&emsp;&emsp;&emsp;ApplyPointwiseFunction <br>&emsp;&emsp;&emsp;&emsp;Animation that applies a pointwise function to a mobject. </b></div>
# <div style="background-color:maroon;color:white"><b>&emsp;&emsp; &emsp;&emsp; syntax<br>
# &emsp;&emsp; &emsp;&emsp;&emsp;&emsp;self.play(function,object,run_time=n)</b><br>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;function</div>&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;complex_to_R3<hr>
# <ol>
#     <li>whats R3</li>
#         <ul>
#             <li>Cartesian space \(\mathbb{R}^{3}\) refers to three-dimensional Euclidean space. In this space, every point, vector, or location is defined by exactly three ordered real numbers (x, y, z). These numbers represent distances along three mutually perpendicular axes.<br>R3 Real three dimensional vector space </li>
#         </ul><hr>
#     <li>Why its used</li>
#         <ul>
#             <li>In 3D animation libraries like 3Blue1Brown's Manim, all graphical coordinates must be represented as 3D vectors (x, y, z).</li>
#             <li>However, mathematical functions involving transformations, mappings, or vector fields are naturally expressed using complex numbers (e.g., f(z) = z²)</li>
#             <li>The complex_to_R3 function provides the bridge:</li>
#          </ul><hr>
#     <li>How it works</li>
#         <ul>
#                             <li>x: extract real_number as x coordinates</li>
#                             <li>y: extract imaginary_number as y coordinates</li>
#                             <li>z: Sets the z-coordinate to 0 to plot it on the default 2D plane of the 3D space. </li>
#         </ul><hr>
#     <li>practical application</li>
#         <ul>
#                             <li>When you want to warp a 2D object or grid using a complex mathematical function, you combine complex_to_R3, your complex function, and R3_to_complex with the ApplyPointwiseFunction animation.</li>
#                             <li>For example, to square the grid using the function f(z) = z², you would write:</li>
#                             <li><span
#                                     style="backgound-color:white;color:red">&emsp;&emsp;self.play(ApplyPointwiseFunction<br>&emsp;&emsp;(lambda point: complex_to_R3(R3_to_complex(point) ** 2), my_mobject))</li></span>
#                             <li>This maps every point on my_mobject to a new position dictated by squaring its complex form, allowing you to animate conformal mappings and complex analysis visually</li>
#         </ul><hr>
#        <li>np.exp()</li>
#                 <ul>
#                     <li>np.exp() is a NumPy function used to calculate the mathematical exponential (\(e^{x}\)) for every element in an input array. The constant e is Euler's number, which is approximately equal to 2.71828.</li>
#                     <li>Element-wise Execution: It calculates \(e^{x}\) for each individual item inside lists or multi-dimensional arrays without requiring a loop.</li>
#                     <li>High Performance: It is vectorized in C, making it significantly faster than standard Python loops or math.exp() when handling large datasets.</li>
#                     <li>Broad Support: It accepts scalars(single number), Python lists, NumPy arrays, and even complex numbers.</li>
#                 </ul>
# </ol>

# %%
from IPython.display import Video
Video('video/warpsquare.mp4', width=400, height=280)
# Out:
# <video src="video/warpsquare.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # 📓-4️⃣ Building Block

# %% [markdown]
# ## mobject

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">self.add | remove-static</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>&emsp;&emsp;&emsp;&emsp;Usually all of the code in a manim script is put inside the construct() method of a Scene class <br>&emsp;&emsp;&emsp;&emsp;This is the principla way of displaying a mobject on the screen when its not being animated <br>&emsp;&emsp;&emsp;&emsp;To remove a mobject from the screen , simply call the remove() method from the containing Scene</b></div>
# <span style="color:cyan;background-color:red;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">self.add | remove turn static into dyanmic .mp4 movie by adding self.wait(n)</span><br>order of the arguments being passed determine the layer on which they reside,<br> therefore if overlapping is to be address, using order to rearrange object on different layer<hr>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Thirteen: prosprac animation | Code Explanation </div>
#
# &emsp;class pospra(Scene)::<br>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;           sqr=Square(color=RED,fill_opacity=0).move_to([0,0,0])<br>
# &emsp;&emsp; &emsp;&emsp;           cir=Circle(color=BLUE, fill_opacity=0).move_to([-1,0,0])<br>
# &emsp;&emsp; &emsp;&emsp;           ci1=Circle(color=BLUE, fill_opacity=0).move_to([1,0,0])<br>
# &emsp;&emsp; &emsp;&emsp;           sta=Star(color=LOGO_WHITE, fill_opacity=0).move_to([0,-0.6,0])<br>
# &emsp;&emsp; &emsp;&emsp;           st1=Star(color=RED_A, fill_opacity=0).move_to([0,0.6,0])<br>
# &emsp;&emsp; &emsp;&emsp;           ci2=Circle(radius=0.2, color=RED).move_to([4,0,0])<br>
# &emsp;&emsp; &emsp;&emsp;           ci3=Circle(radius=0.2, color=RED).move_to([6,0,0])<br>
# &emsp;&emsp; &emsp;&emsp;           un=Union(sqr,cir,ci1,sta,st1, color=LOGO_WHITE, fill_opacity=0.1).move_to([5,0,0])<hr>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(sqr))<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(cir)<br>
# &emsp;&emsp; &emsp;&emsp;          self.play(Create(ci1))<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(sta),run_time=4)<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(st1),run_time=4)<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(un.animate.rotate(PI),run_time=10)<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeIn(ci2),FadeIn(ci3))<br>
# &emsp;&emsp; &emsp;&emsp;           self.play(FadeOut(sqr)  ,FadeOut(cir)  ,FadeOut(ci1) ,FadeOut(sta),FadeOut(st1))<br>
#         &emsp;&emsp; &emsp;&emsp;   self.play(un.animate.move_to([0,0,0]),ci2.animate.move_to([-1,0,0]),ci3.animate.move_to([1,0,0]),run_time=5)<br>

# %% [markdown]
# <table style="border:2px double white">
#      <th>creation of individual objects  </th>
#      <th>union-communal area while adding</th>
#      <th>fading</th>
#     <tr>
#         <td><img src="images/positio (3).png" width="500" height="500"></td>
#         <td><img src="images/positio (2).png" width="500" height="500" ></td>
#         <td><img src="images/positio (1).png" width="500" height="500" ></td>
#      </tr>
# </table>

# %%
from IPython.display import Video
Video('video/pospra.mp4', width=400, height=280)
# Out:
# <video src="video/pospra.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## styling
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">syntax</span>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>set_stroke()<br>&rarr; change the visual style of mobject's border<br>set_fill(color=C,opacity=n)</b><br>&rarr;give visual style to the moject's interior</div>
# <div style="background-color:maroon"><b>set_color()<br>&rarr;0 fully transparent 1 fully opaque
# </div>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Fourteen: styling animation | Code Explanation </div>
#
# &emsp;class styling(Scene):<br>
# &emsp;&emsp;        def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;        cir=Circle().shift(LEFT)<br>
# &emsp;&emsp; &emsp;&emsp;        sqr=Square().shift(UP)<br>
# &emsp;&emsp; &emsp;&emsp;        tri=Triangle().shift(RIGHT)<br>
# &emsp;&emsp; &emsp;&emsp;        cir.set_stroke(color=GREEN,width=20)<br>
# &emsp;&emsp; &emsp;&emsp;        sqr.set_fill(YELLOW,opacity=1)<br>
# &emsp;&emsp; &emsp;&emsp;        tri.set_fill(PINK,opacity=1)<br>
# &emsp;&emsp; &emsp;&emsp;        un=Union(cir , sqr ,  tri).move_to([4,0,0])<hr>
# &emsp;&emsp; &emsp;&emsp;        self.play(Create(sqr))<br>
# &emsp;&emsp; &emsp;&emsp;        self.play(Create(tri))  <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(Create(cir))  <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(Create(un),run_time=6)    <br>
# &emsp;&emsp; &emsp;&emsp;        self.play(un.animate.set_fill(GREEN,opacity=0.6))<br>
# &emsp;&emsp; &emsp;&emsp;        self.wait(1)<br>
# &emsp;&emsp; &emsp;&emsp;        self.play(FadeOut(cir), FadeOut(sqr), FadeOut(tri) )<br>

# %% [markdown]
# <li><b><div style="background-color:yellow;color:indigo;font-size:20px;font-weight:bold">&emsp;&rarr;zorder -layer</b></div></li>
# <table style="border:2px double white">
#      <th>self.add(cir, sqr ,tri)</th>
#      <th>self.add(tri,cir, sqr )</th>
#      <th>self.add(tri, sqr ,cir)</th>
#     <tr>
#         <td>circle is placed on the bottom layer<br>square in the middle<br>triangle on the top</td>
#         <td>square mobject is situated on the bottom layer<br>cirlce is in the middle<br>square is on the top</td>
#         <td>triangle is  placed on the bottom layer while <br>square is the middle <br>circle is located on the front</td>
#      </tr>
#     <tr>
#         <td><img src="images/stylover1.png" width="500" height="500"></td>
#         <td><img src="images/stylover2.png" width="500" height="500" ></td>
#         <td><img src="images/stylover3.png" width="500" height="500" ></td>
#      </tr>
#     <tr>
#         <td><img src="images/styleoverlap_ManimCE_v0.20.11.png" width="500" height="500"></td>
#         <td><img src="images/styleoverlap_ManimCE_v0.20.12.png" width="500" height="500" ></td>
#         <td><img src="images/styleoverlap_ManimCE_v0.20.13.png" width="500" height="500" ></td>
#      </tr>
# </table>
# <li><b><div style="background-color:yellow;color:indigo">&emsp;&rarr;if transparency is 0.5 then it is difficult to tell the difference of overlapping then juding the passing in order of arguemnts</b></div></li>

# %%
from IPython.display import Video
Video('video/styling.mp4', width=400, height=280)
# Out:
# <video src="video/styling.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## animation

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">basics</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>self.play(obj.animate(set_stroke())<br>&emsp;&emsp;&emsp;&rarr; change the visual style of mobject's border<br>self.play(obj.animate(set_fill(color=C,opacity=n))</b><br>&emsp;&emsp;&emsp;&rarr;give visual style to the moject's interior</div>
# <div style="background-color:maroon"><b>self.play(obj.animate(set_color())<br>&emsp;&emsp;&emsp;&rarr;0 fully transparent 1 fully opaque
# </div>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">animate(interpolate_mobject)-Customize !!</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>alpha<br>&rarr;float- between 0 and 1 expressing the ratio to which the <br>the animation is complete.eg.0,0.5,1 are corresponding to 0% 50% 100% completetion</b><br>Manim provides with alpha value in the Interpolate_mobject() method relied<br>based on frame rate of video, rate_function , and run time of animation played<br>&rarr;</div>
# <div style="background-color:maroon"><b>*<br>&rarr;==
# </div>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Fifteen: customized- animation | Code Explanation </div>
# &emsp;class Count(Animation):<br>
# &emsp;&emsp;      def __init__(self, number: DecimalNumber, start: float, end: float, **kwargs) -> None:<br>
# &emsp;&emsp; &emsp;&emsp;             super().__init__(number,  **kwargs)<br>
# &emsp;&emsp; &emsp;&emsp;               self.start = start<br>
# &emsp;&emsp; &emsp;&emsp;               self.end = end<hr>
# &emsp;&emsp;     def interpolate_mobject(self, alpha: float) -> None:<br>
# &emsp;&emsp; &emsp;&emsp;           value = self.start + (self.rate_func(alpha) * (self.end - self.start))<br>
# &emsp;&emsp; &emsp;&emsp;           self.mobject.set_value(value)<hr
# &emsp;class CountingScene(Scene):<hr>
# &emsp;&emsp;    def construct(self):<br>
# &emsp;&emsp; &emsp;&emsp;          number = DecimalNumber().set_color(WHITE).scale(5)<br>
# &emsp;&emsp; &emsp;&emsp;          number.add_updater(lambda number: number.move_to(ORIGIN))<br>
# &emsp;&emsp; &emsp;&emsp;          self.add(number)<br>
# &emsp;&emsp; &emsp;&emsp;          self.wait()<br>
# &emsp;&emsp; &emsp;&emsp;          self.play(Count(number, 0, 100), run_time=100, rate_func=linear)<br>

# %%
from IPython.display import Video
Video('video/CountingScene.mp4', width=400, height=280)
# Out:
# <video src="video/CountingScene.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">animate(coordinates)</span><hr>
#             <div style="background-color:cyan;color:black;">
# <div style="background-color:silver"><b>--<br>&rarr;--<br>--</b><br>--<br>---<br>&rarr;</div>
# <div style="background-color:maroon"><b>*<br>&rarr;==
# </div>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Sixteen: customized- animation | Code Explanation </div>
# &emsp;class animcoor(Scene):<br>
# &emsp;&emsp;      def construct(self):  <br>
# &emsp;&emsp; &emsp;&emsp;         p1 = [-1,-1, 0] <br>
# &emsp;&emsp; &emsp;&emsp;           p2 = [ 1,-1, 0] <br>
# &emsp;&emsp; &emsp;&emsp;           p3 = [ 1, 1, 0] <br>
# &emsp;&emsp; &emsp;&emsp;           p4 = [-1, 1, 0]
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;four corner points coordinates</div>     <hr>
# &emsp;&emsp; &emsp;&emsp;           a  = Line(p1,p2).append_points(Line(p2,p3).points).append_points(Line(p3,p4).points)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#             &emsp;&rarr;line(p1,p2) &nbsp;|horizontal line from lower left to lower right <br>&emsp;&rarr;lline(p2,p3) |vertical line from lower right to upper right <br>&emsp;&rarr;line(p3,p4) |horizontal line from upp</div>  <hr>
# &emsp;&emsp; &emsp;&emsp;           point_start&ensp;&nbsp;&nbsp;= a.get_start() <br>
# &emsp;&emsp; &emsp;&emsp;          point_end&emsp;&nbsp;= a.get_end() <br>
# &emsp;&emsp; &emsp;&emsp;           point_center&nbsp;= a.get_center()
#
# <hr>
# &emsp;&emsp; &emsp;&emsp;           self.add(Text(f"a.get_start() = {np.round(point_start,2).tolist()}",  <br>&emsp;&emsp; &emsp;&emsp;  &emsp;&emsp; &emsp;&emsp;
#                         font_size=24).to_edge(UR).set_color(YELLOW)) <br>
# &emsp;&emsp; &emsp;&emsp;           self.add(Text(f"a.get_end() = {np.round(point_end,2).tolist()}", <br>&emsp;&emsp; &emsp;&emsp;  &emsp;&emsp; &emsp;&emsp;
#                         font_size=24).next_to(self.mobjects[-1],DOWN).set_color(RED)) <br>
# &emsp;&emsp; &emsp;&emsp;           self.add(Text(f"a.get_center() = {np.round(point_center,2).tolist()}", <br>&emsp;&emsp; &emsp;&emsp;  &emsp;&emsp; &emsp;&emsp;
#                         font_size=24).next_to(self.mobjects[-1],DOWN).set_color(BLUE)) <hr>
#
# &emsp;&emsp; &emsp;&emsp;           sdos=VGroup(*[Dot(x) for x in a.points]) <br>
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;all the points that are connected using line.append_points(Line(p2,p3).points)</div>     <hr>
# &emsp;&emsp; &emsp;&emsp;           dot1=Dot(a.get_start()).set_color(YELLOW).scale(2) <br>
# &emsp;&emsp; &emsp;&emsp;           dot2=Dot(a.get_end()).set_color(RED).scale(2) <br>
# &emsp;&emsp; &emsp;&emsp;           dot3=Dot(a.get_top()).set_color(GREEN_A).scale(2) <br>
# &emsp;&emsp; &emsp;&emsp;           dot4=Dot(a.get_bottom()).set_color(GREEN_D).scale(2) <br>
# &emsp;&emsp; &emsp;&emsp;           dot5=Dot(a.get_center()).set_color(BLUE).scale(2) <br>
# &emsp;&emsp; &emsp;&emsp;           dot6=Dot(a.point_from_proportion(0.5)).set_color(ORANGE).scale(2)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;6 dots extracted by get line's position as the line has been connected </div>     <hr>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(sdos),run_time=10) <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(sdos.animate.set_fill(LOGO_GREEN,opacity=1),run_time=5) <br> <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(dot1),Create(dot2), Create(dot3), Create(dot4), Create(dot5), Create(dot6), run_time=10) <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Create(a), run_time=5)

# %% [markdown]
# <li><b><div style="background-color:yellow;color:indigo;font-size:20px;font-weight:bold">&emsp;&rarr;zorder -layer</b></div></li>
# <table style="border:2px double white">
#      <th>Line - connecting two coordinates</th>
#      <th>Dot- boundaries of lines</th>
#      <th>points-connected by line</th>
#     <tr>
#         <td><div style="background-color:white"><br><span style="color:red"> &emsp;&rarr;p1p2</span>
#             &emsp;&rarr;<span style="color:green">p2p3</span> &emsp;&rarr;
#                 <span style="color:blue">p3p4<br></span><br> </div></td>
#         <td><span style="color:yellow">start |-dot1</span>
#             <span style="color:RED">end |-dot2</span>
#             <span style="color:lightgreen">top |-dot3 </span> <br>
#             <span style="color:green">bottom |-dot4</span>
#             <span style="color:lightBLUE">center |-dot5</span>   <br>
#             <span style="color:ORANGE">point_from_proportion(0.5) |-dot6</span>  </td>
#         <td>triangle is  placed on the bottom layer while <br>square is the middle <br>circle is located on the front</td>
#      </tr>
#     <tr>
#         <td><img src="images/anicoline.png" width="500" height="500"></td>
#         <td><img src="images/anicodot.png" width="500" height="500" ></td>
#         <td><img src="images/animcsdo.png" width="500" height="500" ></td>
#      </tr>
# </table>
# <li><b><div style="background-color:yellow;color:indigo">&emsp;&rarr;if transparency is 0.5 then it is difficult to tell the difference of overlapping then juding the passing in order of arguemnts</b></div></li>

# %%
from IPython.display import Video
Video('video/animcsw.mp4', width=400, height=280)
# Out:
# <video src="video/animcsw.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Seventeen: customized- animation | Code Explanation </div>
# &emsp;class animcoor(Scene):<br>
# &emsp;&emsp;      def construct(self):  <br>
# from manim import *
#
# class animcam(Scene):
#     def construct(self):
#         self.camera.background_colo=LOGO_WHITE
#         m1=Square().move_to([2,0,0])
#         m2=Circle().move_to([-2,0,0])
#
#         self.play(Create(m1),Create(m2),run_time=5)
#         self.wait(1)
#         self.play(m1.animate.set_fill(PINK,opacity=0.5))
#         self.wait(1)
#         self.play(m2.animate.set_fill(LOGO_BLUE,opacity=1))
#
#         self.wait(1)
#
#         self.camera.background_color=LOGO_BLACK
#
#         self.play(Transform(m1,m2))
#         self.wait(3)
#
#
#         c1=Circle(radius=0.2,color=WHITE).move_to([-2.5,0.3,0])
#         c2=Circle(radius=0.2,color=WHITE).move_to([-1.5,0.3,0])
#         c11=Circle(radius=0.04,color=BLUE,fill_opacity=1).move_to([-2.5,0.3,0])
#         c12=Circle(radius=0.04,color=BLUE,fill_opacity=1).move_to([-1.5,0.3,0])
#         re=Rectangle(height=0.2,width=0.4).move_to([-2,-0.5,0])
#         tri= Triangle(radius=0.1,color=RED).move_to([-2,0,0])
#
#
#         self.play(Create(c1),Create(c2),Create(c11),Create(c12),Create(re),
#                     Create(tri),run_time=10)
#
#         self.play(FadeOut(m1),FadeOut(c1),FadeOut(c2),FadeOut(re),FadeOut(c11),
#                     FadeOut(c12),FadeOut(tri))

# %%
from IPython.display import Video
Video('video/animcam.mp4', width=400, height=280)
# Out:
# <video src="video/animcam.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <hr>
# <span style="color:cyan;background-color:teal;font-weight:bold;
#              font-size:20px;
#              border:1px dashed white; padding:1px">Thematic Guides -Configuration Command-line Arguments</span><hr>
#             <div style="background-color:cyan;color:black;font-size:20px;font-weight:bold">render</div>
# <ul>
#     <li>manim -fqk filename.py scenename</li>
#         <ul>
#                 <li>f-folder open the directory in which the output is rendered </li>
#         </ul>
#     <li>manim -pqk filename.py scenename</li>
#         <ul>
#                 <li>p-preview open the output using window's default photo viewer or video player </li>
#                     <ol>
#                          <li>qk 4k quality</li>
#                          <li>qp 2k premium quality </li>
#                          <li>qh high quality</li>
#                          <li>qm medium quality</li>
#                          <li>ql low quality</li>
#                     </ol>
#         </ul>
# </ul>
# <ul>
#     <li>manim functionname --help</li>
#     <li>manim --a filename.py scenename&emsp;&emsp;&emsp; &rarr; &emsp; all output types will be rendered including video , pictures</li>
#     <li>manim -s filename.py scenename &emsp;&emsp;&emsp; &nbsp;&rarr; &emsp;  --save_last_frame          Render and save only the last frame of a scene
#                                  as a PNG image.</li>
#     <li> -t, --transparent &emsp;&emsp;&emsp; &emsp;&emsp;&emsp; &emsp;&emsp;&emsp;&emsp;&nbsp;  &rarr; &emsp;   Render scenes with alpha channel.</li>
# </ul>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Eighteen: Frame animation | Code Explanation </div>
# &emsp;class toyexample(Scene):<br>
# &emsp;&emsp;      def construct(self):  <br>
# &emsp;&emsp;  &emsp;&emsp;           orange_square=Square(color=ORANGE,fill_opacity=0.5)  <br>
# &emsp;&emsp;  &emsp;&emsp;           blue_circle  =Circle(color=BLUE,  fill_opacity=1) <br>
# &emsp;&emsp;  &emsp;&emsp;           self.add(orange_square) <br>
# &emsp;&emsp;  &emsp;&emsp;           self.add(blue_circle) <hr>
# &emsp;&emsp;  &emsp;&emsp;           small_dot    =Dot()  <br>
# &emsp;&emsp;  &emsp;&emsp;           small_dot.<span style="color:red;background:cyan;font-weight:bold">add_updater
#     (lambda &emsp;mob: &emsp;mob.next_to(&emsp;blue_circle,&emsp;DOWN&emsp;))</span>  <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(Create(small_dot))   <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(blue_circle.animate.shift(RIGHT*3),run_time=3)   <br>
# &emsp;&emsp;  &emsp;&emsp;           self.wait()  <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(blue_circle.animate.shift(LEFT*3),run_time=3)   <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(ReplacementTransform(orange_square,blue_circle),run_time=5)   <br>
# &emsp;&emsp;  &emsp;&emsp;           self.wait()  <hr>
# &emsp;&emsp;  &emsp;&emsp;           tx=Text("Singer Wan's Rendering of Thematic Guides",color=LOGO_WHITE).shift(UP*2)  <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(Write(tx),run_time=5) <br>
# &emsp;&emsp;  &emsp;&emsp;           self.play(FadeOut(blue_circle, small_dot,tx)) <br>
# &emsp;&emsp;  &emsp;&emsp;           self.wait() <br>

# %%
from IPython.display import Video
Video('video/ShowScreenResolution.mp4', width=400, height=280)
# Out:
# <video src="video/ShowScreenResolution.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Nineteen: Toyexmaple animation using with | Code Explanation </div>
#     from manim import *
# &emsp;class xx(Scene): <br>
# &emsp;&emsp;            def construct(self): <br>
# &emsp;&emsp;  &emsp;&emsp;                   -------------------------------- <hr>
#
#
#
#
#
# &emsp;with tempconfig({"quality":"fourk_quality","preview":True}):<br>
# &emsp;&emsp;     Scene=Scenename()<br>
# &emsp;&emsp;     Scene.render()<hr>
#
# <div style="background-color:yellow;color:blue;font-size:20px;font-weight:bold">terminal:execution syntax :&rarr;<span style="color:white;
#                                                                                                                background-color:indigo"> python filename.py </span></div><hr>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Nineteen: Toyexmaple animation manim execution in terminal| Code Explanation </div>
#     from manim import *
# &emsp;class xx(Scene): <br>
# &emsp;&emsp;            def construct(self): <br>
# &emsp;&emsp;  &emsp;&emsp;                   -------------------------------- <hr>
#
# <div style="background-color:blue;color:cyan;font-size:20px;font-weight:bold">terminal:execution syntax :&rarr;<span style="color:red;background-color:white">  mainim -pqk filename.py scenename</span> </div><hr>

# %%
from IPython.display import Video
Video('video/toyexample.mp4', width=400, height=280)
# Out:
# <video src="video/toyexample.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:black;color:white;font-size:25px;font-weight:bold">Rendering&rarr;<hr>
# <ol><div style="color:green;background-color:white;font-size:20px">
#                                 <li>Scene.setup()</li>
#                                         <ul>
#                                             <li>preparing and setting up the Scene for your animation: eg &rarr; </li>
#                                                 <ul>
#                                                     <li>adding initial mobjects</li>
#                                                     <li>assigning attributes to your scene class</li>
#                                                     <li>etc.</li>
#                                                 </ul>
#                                         </ul></div>
# <div style="color:black;background-color:yellow;font-size:20px">
#                                     <li>Scene.construct()</li>
#                                         <ul>
#                                             <li>which is the script for your screen play and </li>
#                                             <li>&emsp;&emsp; contains programmatic descirptions of your animiations</li>
#                                         </ul></div>
# <div style="color:indigo;background-color:cyan;font-size:20px">
#                                 <li>Scene.tear_down()</li>
#                                         <ul>
#                                             <li>which is intended for any operations you might want to run after on the scene<br> after the last fram has already been rendered eg  </li>
#                                                 <ul>
#                                                     <li>this could run some code that generates a custom thumbnail for the video <br>based on the statr of the objects in the scene</li>
#                                                     <li>this hook is more relevant for situations where manim is used within <br>other python scripts</li>
#                                                 </ul>
#                                         </ul></div><hr>
# <div style="color:blue;background-color:red;font-size:20px">
#                                 <li>actual rendering</li>
#                                         <ul>
#                                             <li>animation by animation with progress bar</li>
#                                         </ul></div>
# </div></ol>
# </div>

# %% [markdown]
# <div style="background-color:black;color:white;font-size:25px;font-weight:bold">Manim Object types&rarr;<hr>
# <ol><div style="color:green;background-color:white;font-size:20px">
#                                             <li>imagemobject :&rarr; which represents images that you can display in your scene</li>
#                                             <li>pmobject &emsp;&emsp;&nbsp;:&rarr; which are very special mobjects used to represent point clouds  </li>
#                                             <li>vmobject &emsp;&emsp;&nbsp;:&rarr; which are vectorized mobject consisted of points that are connected via curves<br>&emsp;&emsp;&emsp;&emsp;&nbsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;&nbsp;&nbsp;Bezier curve</li>
#                                         </ol></div>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Twenty: Bezier curve animation | Code Explanation </div>
# &emsp;class  beziercurve(Scene):<br>
# &emsp;&emsp;      def construct(self):  <br>
#
#
#
#
# &emsp;&emsp;   &emsp;&emsp;           plane = NumberPlane(background_line_style={
#                 "stroke_color": GOLD_E,
#                 "stroke_width": 1,
#                 "stroke_opacity": 0.2
#             })
# &emsp;&emsp;   &emsp;&emsp;           self.play(Create(plane),run_time=3)<br>
#
# &emsp;&emsp;   &emsp;&emsp;           my_vmobject = VMobject(color=GREEN)<hr>
# &emsp;&emsp;   &emsp;&emsp;           <div style="background-color:yellow;color:blue;font-size:15px;font-weight:bold">my_vmobject.points = [
#
#  &emsp;&emsp;   &emsp;&emsp;              np.array([-2, -1, 0]),   &emsp;&emsp;&rarr;&emsp;&emsp;||||start of first curve<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([-3, 1, 0]),    &nbsp;&nbsp;&emsp;&emsp;&rarr;&emsp;&emsp;---first curve's first handle<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([0, 3, 0]),     &nbsp;&nbsp;&nbsp;&emsp;&emsp;&rarr;&emsp;&emsp;---first curve's second handle<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([1, 3, 0]),     &ensp;&nbsp;&emsp;&emsp;&rarr;&emsp;&emsp;||||end of first curve<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([1, 3, 0]),     &nbsp;&nbsp;&nbsp;&emsp;&emsp;&rarr;&emsp;&emsp;>>>>start of second curve<br>
#  &emsp;&emsp;   &emsp;&emsp;             np.array([0, 1, 0]),      &emsp;&emsp;&emsp;&rarr;&emsp;&emsp;---second curve's first handle<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([4, 3, 0]),     &emsp;&emsp;&emsp;&rarr;&emsp;&emsp;---second curve's second handle<br>
#  &emsp;&emsp;   &emsp;&emsp;              np.array([4, -2, 0]) ]   &nbsp;&emsp;&emsp;&rarr;&emsp;&emsp;>>>> end of second curve</div><br>
#
#  &emsp;&emsp;   &emsp;&emsp;          Tex11h=Text("1st Curve's 1st handle",color=RED).scale(0.4).move_to([-3, 1.3, 0])<br>
#  &emsp;&emsp;   &emsp;&emsp;          Tex12h=Text("1st Curve's 2nd handle",color=YELLOW).scale(0.4).move_to([0, 3.3, 0])       <br>
#  &emsp;&emsp;   &emsp;&emsp;          Tex21h=Text("2nd Curve's 1st handle",color=GREEN).scale(0.4).move_to([0, 1.3, 0])<br>
#  &emsp;&emsp;   &emsp;&emsp;         Tex22h=Text("2nd Curve's 2nd handle",color=WHITE).scale(0.4).move_to([4, 3.3, 0])  <br>
#
#  &emsp;&emsp;   &emsp;&emsp;          self.play(Create(Tex11h),run_time=3)    <br>
#  &emsp;&emsp;   &emsp;&emsp;           self.play(Create(Tex12h),run_time=3)<br>
#  &emsp;&emsp;   &emsp;&emsp;          self.play(Create(Tex21h),run_time=3)    <br>
#  &emsp;&emsp;   &emsp;&emsp;          self.play(Create(Tex22h),run_time=3)   <hr>
#
#  &emsp;&emsp;   &emsp;&emsp;          handles = [
#             Dot(point, color=RED) for point in
#             [[-3, 1, 0], [0, 3, 0], [0, 1, 0], [4, 3, 0]]
#         ]<br>
#
# &emsp;&emsp;   &emsp;&emsp;           handleall=VGroup(*handles)<br>
# &emsp;&emsp;   &emsp;&emsp;           self.play(Create(handleall),run_time=4)<br>
#
#  &emsp;&emsp;   &emsp;&emsp;          dot11=Dot()<br>
#  &emsp;&emsp;   &emsp;&emsp;          dot12=Dot()<br>
#   &emsp;&emsp;   &emsp;&emsp;         dot21=Dot()<br>
#   &emsp;&emsp;   &emsp;&emsp;         dot22=Dot()<br>
#
#   &emsp;&emsp;   &emsp;&emsp;         self.play(dot11.animate.set_fill(RED,opacity=1).move_to([-3, 1, 0]),run_time=3)<br>
#   &emsp;&emsp;   &emsp;&emsp;         self.play(dot12.animate.set_fill(YELLOW,opacity=1).move_to([0, 3, 0]),run_time=3)        <br>
#  &emsp;&emsp;   &emsp;&emsp;          self.play(dot21.animate.set_fill(GREEN,opacity=1).move_to([0, 1, 0]),run_time=3)<br>
#  &emsp;&emsp;   &emsp;&emsp;          self.play(dot22.animate.set_fill(WHITE,opacity=1).move_to([4, 3, 0]),run_time=3)    <hr>
#
#  &emsp;&emsp;   &emsp;&emsp;          handle_lines = [
#             Line(
#                 my_vmobject.points[ind],
#                 my_vmobject.points[ind+1],
#                 color=RED,
#                 stroke_width=2
#             ) for ind in range(0, len(my_vmobject.points), 2)
#         ]<br>
#
#   &emsp;&emsp;   &emsp;&emsp;         handle_linesall=VGroup(*handle_lines) <br>
#   &emsp;&emsp;   &emsp;&emsp;         self.play(Create(handle_linesall),run_time=5) <br>
#   &emsp;&emsp;   &emsp;&emsp;         self.add(my_vmobject) <br>
#  &emsp;&emsp;   &emsp;&emsp;          self.wait(4)<br>

# %% [markdown]
# <div style="background-color:black;color:white;font-size:25px;font-weight:bold">Bezier Curve types&rarr;<hr>
# <ol><div style="color:green;background-color:white;font-size:20px">
# <table style="border:4px double gold;">
#     <tr style="font-size:20px;text-align:center;background-color:white;color:indigo;">
#         <th style="border: 2px solid  cyan;" width="300">Types</th>
#         <th style="border: 2px solid  cyan;"width="300">N of control points</th>
#         <th style="border: 2px solid  cyan;"width="300">N of anchor points</th>
#         <th style="border: 2px solid  cyan;"width="300">Syntax</th>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;">straight Bezier Curve</td>
#         <td style="border: 2px solid cyan;">0</td>
#         <td style="border: 2px solid cyan;">2</td>
#         <td style="border: 2px solid cyan;">-</td>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;">quadratic  Bezier Curve</td>
#         <td style="border: 2px solid cyan;">1</td>
#         <td style="border: 2px solid cyan;">2</td>
#         <td style="border: 2px solid cyan;">-</td>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;"><div style="background-color:cyan;color:indigo">cubic  Bezier Curve<br>&emsp;</div></td>
#         <td style="border: 2px solid cyan;">2</td>
#         <td style="border: 2px solid cyan;">2</td>
#         <td style="border: 2px solid cyan;"><div style="background-color:cyan;color:indigo">CubicBezier(start_anchor, start_handle, end_handle, end_anchor, **kwargs)</div></td>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;"><div style="background-color:darkmagenta">spline  -continuous Bezier Curve<br>&emsp;<br>&emsp;<br>&emsp;<br>&emsp;<br>&emsp;<br>&emsp;<br>&emsp;</div></td>
#         <td style="border: 2px solid cyan;">2*n</td>
#         <td style="border: 2px solid cyan;">2*2</td>
#         <td style="border: 2px solid cyan;"><div style="background-color:darkmagenta">variable=VMobject()<hr>variable.points=[<br>np.array([x, y, z]), <br>np.array([x, y, z]), <br>---]<br>  &emsp; </div></td>
#     </tr>
# </table>
# </div>

# %%
from IPython.display import Video
Video('video/beziercurve11.mp4', width=400, height=280)
# Out:
# <video src="video/beziercurve11.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/BezierSplineExample.mp4', width=400, height=280)
# Out:
# <video src="video/BezierSplineExample.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:black;color:black;font-size:25px;font-weight:bold">Mobject Initialization&rarr;<hr>
# <ol><div style="color:green;background-color:black;font-size:20px">
# <table style="border:4px double white;text-align:left">
#     <tr style="font-size:20px;text-align:left;background-color:white;color:indigo;">
#         <th style="border: 2px solid  cyan;" width="400">inheritance .super()</th>
#         <th style="border: 2px solid  cyan;" width="400">example1</th>
#         <th style="border: 2px solid  cyan;" width="400">example2</th>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;">level1 </td>
#         <td style="border: 2px solid cyan;">polygon</td>
#         <td style="border: 2px solid cyan;">TipableMobject</td>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;">level2</td>
#         <td style="border: 2px solid cyan;">rectangle</td>
#         <td style="border: 2px solid cyan;">arc</td>
#     </tr>
#     <tr style="border: 2px solid cyan;">
#         <td style="border: 2px solid cyan;"><div style="background-color:black;color:yellow">level3<br>&emsp;</div></td>
#         <td style="border: 2px solid cyan;"><div style="background-color:black;color:yellow">square<br>&emsp;</div></td>
#         <td style="border: 2px solid cyan;"><div style="background-color:black;color:yellow">circle | curved arrow<br>&emsp;</div></td>
#     </tr>
# </table>
# </div>

# %% [markdown]
# <div style="background-color:silver;font-size:20px;color:indigo;font-weight:bold">Animation and Renderloop</div>
# <ul style="list-style-type:circle">
#     <li>Initializing Animations </li>
#         <ol>
#             <li>animation begin()</li>
#             <li><span style="color:red;font-weight:bold;background-color:cyan;border:2px dotted blue">animation finish()</span></li>
#             <li>animation interpolate()</li>
#         </ol>
#     <li>The play call<br> &emsp;&emsp; preparing to enter manim's render loop&emsp;&emsp; &rarr; Scene.play()</li>
#     <li>The real render loop</li>
#         <ol>
#             <li>Cario render (save_static_frame_data()) </li>
#             <li>Scene.play_internal()</li>
#         </ol>
#     <li>completing the render loop</li>
#         <ol>
#             <li><span style="color:red;font-weight:bold;background-color:cyan;border:2px dotted blue">animation finish()</span></li>
#             <li>animation clean_up_from_scene()</li>
#         </ol>
# </ul>

# %% [markdown]
# ## <div style="background-color:green"><li>Text<br> &emsp;</li>
# <ol>
#         <li>latex-syntaxt</li>
#             <ul>
#                 <li>varible=Text(xx  frac {2} {33} ,font_size=20,---).method()</li>
#                 <li>varible=Text("xx $\frac{2}{33}$",font_size=20,---).method()</li>
#             </ul>
#         <li>Regular text -pango-syntaxt</li>
#             <ul>
#                         <li>varible=Text("xx",font_size=20,---).method()</li>
#                         <li>Text() class uses Pango library to render text </li>
#                         <div style="background-color:green;color:white"><li>working with regular text</li>
#                             <ul>
#                                 <li>font size and family</li>
#                                             <div style="background-color:white;
#                                                         color:indigo;font-weight:bold;
#                                                         border:2px dotted black"><li>syntaxt : variable = Text(
#                                                             font="Noto Sans", font_size=20 &rarr;&emsp;font="x" setting the font family
#                                                 </li>
#                                                 <li>how to get a complete list of pnago font family in terminal</li>
#                                                 <ol>
#                                                     <li>>>>python</li>
#                                                     <li>>>> import manimpango</li>
#                                                     <li>>>> manimpango.list_fonts()</li>
#                                                 </ol>    </div>
#                                 </ul>
#                                 <li>setting slant and weight</li>
#                                 <li>using colors -syntax</li>
#                                     <ul>
#                                                 <div style="background-color:red;
#                                                         color:indigo;font-weight:bold;
#                                                         border:2px dotted magenta"><ol>
#                                                     <li>>>>World=Text("World", t2c={'[ 1:-2 ]' : RED } ).move_to(RIGHT)</li>
#                                                             <ul>
#                                                                 <li>parameter t2c text to color </li>
#                                                                 <li>syntax &rarr; breakdown</li>
#                                                                     <ol>
#                                                                         <li>varable=Text("str", t2c= {dictionary}</li>
#                                                                         <li>dictionary format &nbsp;{ '[slicing]' : COLOR &emsp;}</li>
#                                                                         <li>--------------------- { '[range]' : argument }</li>
#                                                                     </ol>
#                                                             </ul>
#                                                     <li>>>>World=Text("World",color=RED</li>
#                                                 </ol></div>
#                                     </ul>
#                                 <li>using gradients -syntax</li>
#                                     <ul>
#                                                 <div style="background-color:lightblue;
#                                                         color:indigo;font-weight:bold;
#                                                         border:2px dotted magenta"><ol>
#                                                     <li>>>> t2gworld=Text("World",
#                         t2g={"World":(WHITE,YELLOW,TEAL,PINK)}).move_to(RIGHT)</li>
#                                                             <ul>
#                                                                 <li> parameter t2g text to gradient </li>
#                                                                 <li>syntax &rarr; breakdown</li>
#                                                                     <ol>
#                                                                         <li>varable=Text("str", t2g= {dictionary}</li>
#                                                                         <li>dictionary format &nbsp;{ '[slicing]' : (COLOR1,COLOR2,---- &emsp;}</li>
#                                                                         <li>--------------------- { '[range]' : sequential arguments separated by comma and wrapped in a pair of parenthese }</li>
#                                                                     </ol>
#                                                             </ul>
#                                                             </ul>
#                                                     <li>>>> -- </li>
#                                                 </ol></div>
#                                     </ul>
#                                 <li>setting line space</li>
#                                     <ul>
#                                                             <div style="background-color:blue;
#                                                         color:white;font-weight:bold;
#                                                         border:4px double silver"><ul>
#                                                                 <li>syntax &rarr; breakdown</li>
#                                                                     <ol>
#                                                                         <li> varable = Text( "str" , <span style="background-color:yellow;color:black">&emsp;line_space=n&emsp;</span>&emsp;)</li>
#                                                                     </ol>
#                                     </ul>
#                                                             </ul></div>
#                                 <li>Disabling Ligatures❗</li>
#                                     <ul>
#                                         <li>By disabling ligatures you would get a one-to-one mapping between characters and submobjects.<br> This fixes the issues with coloring text.
# </li>
#                                     </ul>
#                                 <li>Iterating text</li>
#                                     <ul>
#                                         <li>Text objects behave like VGroups. Therefore, you can slice and index the text.<br>
# For example, you can set each letter to different color by iterating it using for loop</li>
#     <div style="background-color:blue;
#                                                         color:white;font-weight:bold;
#                                                         border:4px double silver"><ul>
#                                                                 <li>syntax &rarr; breakdown</li>
#                                                                     <ol>
#                                                                         <li>
#         for letter in text:<br>
#             &emsp;&emsp;letter.set_color(random_bright_color()) , <span style="background-color:yellow;color:black">&emsp;random_color()&emsp;</span>&emsp;)</li>
#                                                             </ul></div>
#                                     </ul>
#                             </ul>
#             </ul>
#         <li>markup text-nested formatting-syntaxt</li>
#             <ul>
#                 <li>varible=<span style="background-color:cyan;color:black;
#                                 font-weight:bold">MarkupText(f'xxx < span fgcolor= "{ }"  xxx < /span >', color=RED<)</span>.method()</li>
#
# <li>latex</li>
#             <ul>
#                 <li>syntax<span style="background-color:cyan;color:black;
#                                 font-weight:bold"> MathTex(r"\frac{3\pi}{2}"),</span></li>
#             </ul>
# </ol></div>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Twenty-One: Text animation | Code Explanation </div>
# &emsp;class text1(Scene):<br>
# &emsp;&emsp; def construct(self):     <br>
# &emsp;&emsp; &emsp;&emsp;         text1=Text("Hello World",font_size=144,color=LOGO_RED)  <br>
# &emsp;&emsp; &emsp;&emsp;           self.play(Write(text1),run_time=3)   <br>
# &emsp;&emsp; &emsp;&emsp;              self.play(text1.animate.set_fill(LOGO_GREEN,opacity=0.5),run_time=3)  <br>
# &emsp;&emsp; &emsp;&emsp;            self.wait(3) <br>

# %% [markdown]
# ## <div style="background-color:green"><li>Paragraph<br> &emsp;</li>
# <div style="background-color:teal"><ol>
#         <li>latex-syntaxt</li>
#             <ul>
#                 <li>variable=Paragraph("xx","xx","xx")</li>
#                 <li>            for line in paragraph:
#                 line.set_color(random_color())
#                 self.play(Write(line),run_time=1)</li>
#             </ul>
# </ol></div>

# %%
from IPython.display import Video
Video('video/text1.mp4', width=400, height=280)
# Out:
# <video src="video/text1.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Twenty-Two: text2pango MarkupText-animation | Code Explanation </div>
# &emsp;class text2pango(Scene):<br>
# &emsp;&emsp;    def construct(self):  <br>
# &emsp;&emsp; &emsp;&emsp;         text11=MarkupText(
#                             f'&emsp;all in red     < span fgcolor="{ YELLOW }">except this &emsp;< /span>',
#                             color=RED  )  <br>
#                              <div style="border:1px dotted white;background-color:indigo">&emsp;&emsp; &emsp;&emsp;&emsp;&emsp; f &rarr; format "<></>" &rarr; < span parameter="{ argument } > xx < /span> , parameter=argument)"</div>
# &emsp;&emsp; &emsp;&emsp;           sself.play(Write(text11),run_time=3)   <br>
# &emsp;&emsp; &emsp;&emsp;            self.wait(2) <br>

# %%
from IPython.display import Video
Video('video/markuptext.mp4', width=400, height=280)
# Out:
# <video src="video/markuptext.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div style="background-color:white;font-size:20px;
#     font-weight:bold;
#     color:teal">Example Twenty-Three: pangofont animation | Code Explanation </div>
# &emsp;class pangofont(Scene):<br>
# &emsp;&emsp;       def construct(self): <br>
# &emsp;&emsp; &emsp;&emsp;                 tx1=Text("AMGDT",font='AMGDT')<br>
# &emsp;&emsp; &emsp;&emsp;                 self.play(Write(fon),run_time=2) <br>
# &emsp;&emsp; &emsp;&emsp;                  self.play(FadeOut(fon),run_time=2)
# &emsp;&emsp; &emsp;&emsp;        <hr> <div style="background-color:silver;color:blue">
# &emsp;&emsp; &emsp;&emsp;    ---repeating<br>&emsp;<br></div>
# &emsp;&emsp; &emsp;&emsp;        <hr>

# %%
from IPython.display import Video
Video('video/pangofont.mp4', width=400, height=280)
# Out:
# <video src="video/pangofont.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### <div style="background-color:cyan;color:indigo"> manim pango font style <br>&emsp;</div>
#  <img src="images/pangofontsta_ManimCE_v0.20.1.png"
#                 alt="pangofontsta_ManimCE_v0.20.1.jpg" width="1200" height="1100">

# %%
from IPython.display import Video
Video('video/pangofontanim.mp4', width=400, height=280)
# Out:
# <video src="video/pangofontanim.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/textcolor.mp4', width=400, height=280)
# Out:
# <video src="video/textcolor.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/textgradient.mp4', width=400, height=280)
# Out:
# <video src="video/textgradient.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/linspacing.mp4', width=400, height=280)
# Out:
# <video src="video/linspacing.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/textligature.mp4', width=400, height=280)
# Out:
# <video src="video/textligature.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/textvectorized.mp4', width=400, height=280)
# Out:
# <video src="video/textvectorized.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <table >
#     <th>rate_func </th>
#         <tr>
#             <td><img src="images/ratefunc.png" width="1000" height="400"></td>
#          </tr>
#     <td><div style="color:yellow;background-color:black"><span style="color:white">vertical</span> vs <span style="color:cyan">horizontal</span> |4 types<hr>
#
# <li><span style="color:yellow">&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;smooth <br>&emsp;&emsp; 0-1 half of a bell curve</span></li>
#
# <li><span style="color:brown">&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;linear <br>&emsp;&emsp; 0-1 diagonal straight line</span></li>
#
# <li><span style="color:green">&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;lamda t: smooth(1-t)<br>&emsp;&emsp; 1-0 half of a bell curve</span></li>
#
# <li><span style="color:lightpurple">&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;there and back<br>&emsp;&emsp; 0-1 full bell curve</span></li><hr>
#                     <li>&emsp;&emsp;&emsp;<span style="color:white">vertical movemnet is what characterizes each rate function</span><br>
#                     &emsp;&emsp;&emsp;0-1 is the lowest to the highest point </li><hr>
#                     <li>&emsp;&emsp;&emsp;<span style="color:cyan">horizontal movement is associated with time</span><br>
#                     &emsp;&emsp;&emsp;0-1 for example 4 second -25% is 1 second 50% 2 75% 3 100% 4 </li><hr>
#
# </ul>
# </td>
# </table>

# %% [markdown]
# <div style="background-color:green;font-size:20px">Animation Keyword Arguments</div>
# <ul style="list-style-type:circle">
#     <li>moject &emsp;&nbsp;-<span style="color:red;font-weight:bold;background-color:cyan">every</span>
#         animation is tied to a mobject</li>
#     <li>run_time &nbsp;-🕒the animation's play duration|FadeIn</li>
#     <li>rate_func&nbsp;- a function r:&emsp;[0,1]&rarr;&emsp;[0,1]&nbsp;controlling animation progression&rlarr;completion percentage ratio</li>
#     <li>more technical ,less relevant ones</li>
# </ul>
# <div style="background-color:cyan;color:black;font-size:20px">Basic Mechanisms of Scene.play </div>
# <ul style="list-style-type:circle">
#     <li><span style="color:indigo;font-weight:bold;background-color:white">Multiple animations can be passed as positional arguments</span> <br>
#         &emsp;&emsp;self.play(anim1 , anim2)</li>
#     <li>passing animation keyword arguments propogates them to all animations <br>
#         &emsp;&emsp;self.play(anim1 ,anim2 , run_time=3</li>
#     <li>Manim will not error if you try to pass conflicting animations , it can't combine different animations for you!<br>&emsp;&emsp;self.play(Rotate(s, PI) , Rotate
#         (s, <span style="color:red;font-size:15px;font-weight:bold">-PI)
#         Manim will execute the last one</span></li>
#     <li>more technical ,less relevant ones</li>
# </ul>
#
# <div style="background-color:cyan;color:black;font-size:20px">Overlapping animations  </div>
# <ol>
#     <li>useful for grouping animations: <b>AnimationGroup</b></li>
#     <li>like_group or VGroup , but for animations</li>
#     <li>keyword argument <b><span style="background-color:cyan;color:indigo">lag_ratio</span></b> ,
#         number between 0 and 1 controls whether animations are played
#         <ol style="list-style-type:circle">
#                 <li>&emsp;&emsp;simultaneously(<span style="background-color:cyan;color:maroon">0</span>)</li>
#                 <li>&emsp;&emsp;successively&emsp;(<span style="background-color:darkmagenta;color:white"> 1
#                 </span>)</li>
#                 <li>&emsp;&emsp;anything in between</li>
#         </ol>
#     <li>finer control possible by editing list in anims_with_timings attribute</li>
# </ol>

# %% [markdown]
# <div style="background-color:green;font-size:20px">the .animate syntax</div>
# <ul style="list-style-type:circle">
#     <li>problem &emsp;&nbsp;-<span style="color:red;font-weight:bold;background-color:cyan">mobj.method()</span>
#         usually returns a mobject, mobjects can't be passed to play</li>
#     <li>solution &nbsp;Mobjects have a <span style="color:red">.animate property</span>
#         which can build animations!</li>
#     <li>✅correct syntax examples</li>
#             <ol>
#                 <li>▶self.play(s.animate.shift(RIGHT)<br>
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     animation of shift to RIGHT</li>
#                 <li>🔎self.play(s.animate(run_time=2),scale(3))<br>
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     supports animation keywords</li>
#                 <li>⛓self.play(s.animate.scale(1/2).shift(2*LEFT)<br>
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     supports chaining</li>
#                 <li>👨‍👩‍👧‍👦self.play(VGroup(s,c).animate.arrange(RIGHT,buff=1))<br>
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#                     supports <span style="background-color:red">VGroup</span></li>
#             </ol>
# </ul>

# %% [markdown]
# <div style="border: 20px solid gold; padding: 5px; font-size:20px;font-weight:bold;color:red;display: inline-block;background-color:lightgreen">
#   Note:
# </div>
# .animate is not aware of <b><u>how your mobjects change</u></b> , but knows only <br>
# konws start & end and interpolates <span style="color:white;
#                                        background-color:darkmagenta">linearly</span>
#                                        between them!
#
# <hr>
# <div style=" font-size:20px;font-weight:bold;color:white;background-color:blue">
#   Related animations : <span style="color:cyan">One:MoveToTarget:</span> and
#     <span style="color:maroon">Two:Restore:</span></div>
# <ul>
#     <li>General philosophy</li>
#         <ol>
#             <li>create a copy of a mobject</li>
#             <li>modify it however you like</li>
#             <li>transform between </li>
#                 <ul>
#                     <li>original mobject and</li>
#                     <li>modified copy</li>
#                 </ul>
#         </ol><hr>
#     <li><span style="color:cyan;background-color:blue">One:MoveToTarget:</span></li>
#         <ol>
#             <li>call <span style="border: 1px dashed cyan; padding: 2px;
#                                                       background-color:blue">mob.generate_target()</span></li>
#             <li>modify mob.target</li>
#             <li>animate with <span style="border: 1px dashed cyan; padding: 2px;
#                                                       background-color:blue">MoveToTarget(mob)</span></li>
#         </ol>
#     <li><span style="color:white;background-color:maroon">Two:Restore:</span></li>
#         <ol>
#             <li>call <span style="border: 1px dashed cyan; padding: 2px;
#                                                       background-color:maroon">mob.save_state()</span></li>
#             <li>keep modifying mob </li>
#             <li>animate return to save state with <span style="border: 1px dashed cyan; padding: 2px;
#                                                       background-color:maroon">Restore(mob)</span></li>
#         </ol>
# </ul>

# %% [markdown]
# <div style=" font-size:20px;font-weight:bold;color:white;background-color:indigo">
#     <span style="color:cyan">Custom</span>  Animations via
#     <span style="color:red">Functions</span></div>
# <ul>
#     <li>Abstraction</li>
#         <ul style="list-style-type:circle;">
#             <li>an animation is a function mapping( mobject, completion ratio ) to a mobject</li>
#         </ul>
#     <li>example</li>
#         <ul style="list-style-type:circle;">
#             <li>def move_somewhere(mobj,alpha):<br>&emsp;&emsp;
#                 mobj.move_to(alpha * RIGHT + alpha ** 2 * 2 * UP)</li>
#         </ul>
#     <li>UpdateFrom<span style="color:cyan">Alpha</span>Func</li>
#         <ul style="list-style-type:circle;">
#             <li>Given such a function, UpdateFromAlphaFunc constructs the corresponding animation!</li>
#         </ul>
#     <li><span
#             style="color:green;font-size:20px;
#             background-color:cyan;
#             font-weight:bold;
#             border:2px double blue;padding:2px">Tip🔆</span></li>
#         <ul style="list-style-type:circle;">
#             <li>store initial state in customer mobject attribute to allow for more flexibility!</li>
#             <li>mobj.initial_position = mobj.get_center()</li>
#             <li>mobj.initial_position is available in the animation function or </li>
#             <li>write custome animation</li>
#         </ul>
#     <li><span
#             style="color:darkmagenta;font-size:20px;
#             background-color:white;
#             font-weight:bold;
#             border:2px double gold;padding:2px">(1-t)🕛</span></li>
#        <ul>
#             <li>application examples</li>
#                 <ul style="list-style-type:circle;">
#                     <li>rate_func(lambda t: smooth(1-t)</li>
#                     <li>set_opacity(1-t)</li>
#                 </ul>
#             <li>explanation</li>
#                 <ul style="list-style-type:none;color:cyan;font-weight:bold"><hr>
#                     <li>rate_func(1-t) is a common technique for time-reversal.
#                         It plays an animation backwards  <br>
#                         (from 100% completion to 0%),or flips a timing function's easing behavior <br>
#                         (e.g., changing Ease-In to Ease-Out). <hr></li>
#        </ul>
# </ul>

# %% [markdown]
# <div style="
#             text-decoration:overline;
#             border-radius:5px;
#             border: 10px double blue;
#             padding: 10px; font-size:20px;
#             font-weight:bold;color:black;
#             display: block;
#             background: radial-gradient(ellipse at center, #CE5911 0%, #1C6EA4 20%, #C55FAB 100%);">
#   Anatomy of Animations:✏
# </div>
# <div style="
#             font-size:15px;
#             text-decoration:none;
#             font-weight:bold;color:white;
#             display: block;">
#   Animation methods called in a lifecycle
# </div><hr>

# %% [markdown]
# <hr>
# <ul style="list-style-type:disk">
#     <li>_init_()</li>
#         <ul style="list-style-type:circle;">
#             <li>initial stage: _init_ call from initialization to the construction of your scene<br>
#                 and finally it reaches to the point of self.play() call that contains your animation</li>
#             <li><div style="background-color:yellow;color:black;
#                     font-weight:bold">eg code: <br>
#             &emsp;class Disperse(Animation): <br>
#             &emsp;&emsp;def __init__(self, mobject, dot_radius=0.05, dot_number=100, **kwargs):
#                 &emsp;&emsp;&emsp;super().__init__(mobject, **kwargs)<br>
#                 &emsp;&emsp;&emsp;self.dot_radius = dot_radius<br>
#                 &emsp;&emsp;&emsp;self.dot_number = dot_number<br></div></li>
#             <li><div style="background-color:brown;color:white;
#                     font-weight:bold"><hr>eg code-explanation: <br>
#             &emsp;class Disperse(Animation): &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;|the class is not inherited form
#                 Scene class but from Animation</div>
#                &emsp;&emsp;<span style="background-color:yellow;color:black;
#                                             font-weight:bold">def __init__</span>(self, mobject,
#                 dot_radius=0.05, dot_number=100,
#                 <span style="background-color:cyan;color:black;
#                                             font-weight:bold">&emsp;**kwargs&emsp;</span>)
#                 &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;|specify the instance_number and instance_radius of the dots by overriding
#                 the _init_class | &emsp;&emsp;syntax: def _init_(self, mobject,
#                 objectname_parameter = argument,<span style="background-color:cyan;color:black;
#                                             font-weight:bold">&emsp;**kwargs&emsp;</span>)
#                 &emsp;&emsp;&emsp;&emsp;<span style="background-color:cyan;color:black;
#                                             font-weight:bold">&emsp;**kwargs&emsp;</span> without
#                 passing any argument means it will
#                 inherit whatever property parent class has
#                 </div>
#                 &emsp;&emsp;&emsp;super().__init__(mobject, **kwargs)
#                 &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;| when calling the parent class use super() without passing self
#                     |<br> &emsp;&emsp; and then pass in the mobject ,and all the arguemnts that you
#                     <br> &emsp;&emsp; want to access.
#                 </div>
#                 &emsp;&emsp;&emsp;self.dot_radius = dot_radius<br>
#                 &emsp;&emsp;&emsp;self.dot_number = dot_number
#                 &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;using self.attribute to gain access to the properties that you want.
#                 </div>
#             </li>
#        </ul>
#     <li>begin()</li>
#         <ul style="list-style-type:circle;">
#             <li>prepares first animation frame:<br>
#                 stores mobject copy in self.starting_mobject</li>
#             <li><div style="background-color:beige;color:blue;
#                     font-weight:bold">eg code: <br>
#         &emsp;def begin(self):<br>
#         &emsp; &emsp;dots = VGroup(
#         &emsp; &emsp;*[Dot(radius=self.dot_radius).move_to(self.mobject.point_from_proportion(p))<br>
#         &emsp; &emsp;for p in np.linspace(0, 1, self.dot_number)])
#         &emsp; &emsp;for dot in dots:<br>
#         &emsp; &emsp;dot.initial_position = dot.get_center()<br>
#         &emsp; &emsp;dot.shift_vector = 2*(dot.get_center() - self.mobject.get_center())<br>
#         &emsp; &emsp;dots.set_opacity(0)<br>
#         &emsp; &emsp;self.mobject.add(dots)<br>
#         &emsp; &emsp;self.dots = dots
#         &emsp; &emsp;super().begin()<br>
#         &emsp; &emsp;class Disperse(Animation):
#         <li><div style="background-color:blue;color:beige;
#                     font-weight:bold">eg code explanation: </div>
#         &emsp;def begin(self):<br>
#         &emsp; &emsp;dots = VGroup(
#         &nbsp;*[Dot(radius=self.dot_radius).move_to(self.mobject.point_from_proportion(p))<br>
#         &emsp; &emsp;for p in np.linspace(0, 1, self.dot_number)])
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;*[] unpack a list <br>
#          &emsp;to space the dots equally , use numpy linspace-why 0,1 work, -the redius is 0.05 which
#         <br> &emsp; is proportional to the maxium value 1 set radius using radius paremeter assigned with
#             <br> &emsp;self.radius , and then position them use move_to method , by using point_from_proportion(p)
#                 </div>
#         &emsp;for dot in dots:<br>
#         &emsp; &emsp;dot.initial_position = dot.get_center()<br>
#         &emsp; &emsp;dot.shift_vector = 2*(dot.get_center() - self.mobject.get_center())
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;first get_center which is the initial poistion prior to the dispersion<br>
#          &emsp;move the dots in the opposition direction of the mobject - dispersion movement
#         <br> &emsp; and then it will scatter around the edge of the mobject
#             <br> &emsp; calculation formula : dot.shift_vector = dot - mobj
#                 </div>
#         &emsp; &emsp;dots.set_opacity(0)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;by setting the dot's opacity to 0 , the Scene won;t show， because we don't
#             want overlap<br>&emsp;. However, if its initially set to opacity 0, it will slowly fadein. </div>
#         &emsp; &emsp;self.mobject.add(dots)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;then we set the dots as the child object of the original object<></div>
#         &emsp; &emsp;self.dots = dots
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp;set the dots group as the attribute of the animation so that you may gain directly access
#             <br>&emsp; to them instead of using parent -child relationship
#         &emsp; &emsp;super().begin()<br>
#         &emsp; &emsp;class Disperse(Animation):</div>
#         </ul>
#     <li>interpolate_mobject(alpha)</li>
# <ul style="list-style-type:circle;">
#             <li>brings self.mobject to the state of $\alpha$% of animation completed<br>
#                 default: delegates to submojects | $\alpha$ : &rarr; completion ratio <br> :
#                 children submoject should organize themselves insetad of relying on their
#                 parent to handle everything </li>
#             <li><div style="background-color:blue;color:beige;
#                     font-weight:bold">eg code: <br>
#         &emsp;def interpolate_mobject(self, alpha):<br>
#         &emsp;&emsp;&emsp;alpha = self.rate_func(alpha)  # manually apply rate function<br>
#         &emsp;&emsp;if alpha <= 0.5:<br>
#         &emsp;&emsp;&emsp;self.mobject.set_opacity(1 - 2*alpha, family=False)<br>
#         &emsp;&emsp;&emsp;self.dots.set_opacity(2*alpha)<br>
#         &emsp;&emsp;else:<br>
#         &emsp;&emsp;&emsp;self.mobject.set_opacity(0)<br>
#         &emsp;&emsp;&emsp;self.dots.set_opacity(2*(1 - alpha))<br>
#         &emsp;&emsp;for dot in self.dots:<br>
#                 &emsp;&emsp;&emsp;dot.move_to(dot.initial_position + 2*(alpha-0.5)*dot.shift_vector)</div>
#             <li><div style="background-color:green;color:beige;
#                     font-weight:bold">eg code: explanation <br>
#         &emsp;def interpolate_mobject(self, alpha):
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp; override the interpolate_mobject &emsp;|&emsp;
#             alpha or t time fadeout the mobject at the same fadein the dots </div>
#         &emsp;&emsp;if alpha <= 0.5:
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp; it handles the first half of the animation</div>
#         &emsp;&emsp;&emsp;self.mobject.set_opacity(1 - 2*alpha, family=False)<br>
#         &emsp;&emsp;&emsp;self.dots.set_opacity(2*alpha)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#                 &emsp; family=False means child,dots, is not concered  at this phase<br>
#             &emsp;break down  alpha=0
#             <ul>
#                 <li>1-2*alpha when $\alpha$ is 0, mobject is fully visible </li>
#                 <li>dots are invisible</li>
#             </ul>
#             &emsp;break down  alpha=0.5
#             <ul>
#                 <li>1-2*alpha when $\alpha$ is 0.5, mobject is  invisible </li>
#                 <li>dots are fully visible</li>
#             </ul>
#         </div>
#         &emsp;&emsp;else:
#         &emsp;&emsp;<div style="color:cyan;border:dotted beige">
#                 &emsp; it handles the second half of the animation dots grow dimmer until invisible <br>
#                 &emsp;&emsp; on the other hand , the mobject remains invisible during the entire duration</div>
#         &emsp;&emsp;&emsp;self.mobject.set_opacity(0)<br>
#         &emsp;&emsp;&emsp;self.dots.set_opacity(2*(1 - alpha))
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#             &emsp;break down  alpha=0.5
#             <ul>
#                 <li> mobject is invisible as its set at static constant 0 </li>
#                 <li>dots are fully visible</li>
#             </ul>
#             &emsp;break down  alpha=1
#             <ul>
#                 <li>mobject is still invisible as its set at static constant 0</li>
#                 <li>2*(1-$\alpha$) =0 dots are now fully invisible as </li>
#             </ul>
#         </div>
#         &emsp;&emsp;for dot in self.dots:<br>
#                 &emsp;&emsp;&emsp;dot.move_to(dot.initial_position + 2*(alpha-0.5)*dot.shift_vector)
#         &emsp;&emsp;<div style="color:yellow;border:dotted beige">
#             &emsp;move dots
#             &emsp;break down  alpha=0.5
#             <ul>
#                 <li> dots are at the center becuase 2*($\alpha$ 0.5-0.5)=0  </li>
#             </ul>
#             &emsp;break down  alpha=1
#             <ul>
#                 <li> dots are at the farthest position becuase 2*($\alpha$ 1-0.5=0.5)=2*0.5=1</li>
#             </ul></div>
# </ul>
#    <li>interpolate_submoject(sub,sub_start,alpha)</li>
# <ul style="list-style-type:circle;">
#             <li>same as above, but for a specific submoject (in argument)</li>
#        </ul>
#     <li>finish()</li>
# <ul style="list-style-type:circle;">
#             <li>finishes animation, produces last frame</li>
#             <li><div style="background-color:cyan;color:indigo;
#                     font-weight:bold">eg code: <br>
#             &emsp;   </div>
#         </ul>
# <li>clean_up_from_scene(scene)</li>
# <ul style="list-style-type:circle;">
#             <li>all remaining mobject and scene cleanup (e.g. removing mobjects)</li>
#             <li><div style="background-color:yellow;color:brown;
#                     font-weight:bold">eg code: <br>
#             &emsp;def clean_up_from_scene(self, scene):<br>
#         super().clean_up_from_scene(scene)<br>
#         scene.remove(self.dots)</div>
#             <li><div style="background-color:yellow;color:brown;
#                     font-weight:bold">eg code explanation: <br>
#             &emsp;def clean_up_from_scene(self, scene):<br>
#         super().clean_up_from_scene(scene)
#         &emsp;&emsp;<div style="color:black;border:dotted indigo">
#                 &emsp;calling the clean up method for the parent</div>
#         scene.remove(self.dots)
#         &emsp;&emsp;<div style="color:black;border:dotted indigo">
#                 &emsp; remove dots from the scene</div>
#         </ul>

# %% [markdown]
# <hr>
# <div style="background-color:silver;color:maroon">
# class CustomAnimationExample(Scene):<br>
# &emsp;def construct(self):<br>
# &emsp;&emsp;st = Star(color=YELLOW, fill_opacity=1).scale(3)<br>
# &emsp;&emsp;self.add(st)<br>
# &emsp;&emsp;self.wait()<br>
# &emsp;&emsp;self.play(<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<span
#                                                 style="color:yellow;font-weight:bold;background-color:indigo;">
#                                                 Disperse</span><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;(st, dot_number=200,<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;run_time=4))<br>
# <hr>
# <span style="color:yellow;font-weight:bold;background-color:indigo;">customanimationfunction</span><br>
# </div>
# <hr>

# %% [markdown]
# <table>
#     <th width="333.3333">star   </th>
#     <th width="333.3333">star+dots   </th>
#     <th width="333.3333">dots   </th>
#     <tr>
#         <td><img src="images/cusfunc1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/cusfunc2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/cusfunc3.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>

# %% [markdown]
# # 📓-7️⃣ Updater Function

# %% [markdown]
# <hr>
# <div style="background-color:cyan;color:indigo">
# <div style="border:10px double blue;font-size:20px;font-weight:bold;color:white;background-color:red">Workflow of flame rendering :</div>
# <ol>
#     <li>It set up time lines in which the scene will be evaluated and the mobjects positioned</li>
#     <li>At these time points, it constructs frames:</li>
#         <ul>
#             <li>camera <u>captures</u> one of the frames</li>
#             <li>and then <u>renders</u> it</li>
#             <li>the process depends on your <u>frame rate</u> setting</li>
#         </ul>
#     <li>before the rendering of a frame , the updater functions are called</li>
# </ol>
# </div>
# <hr>

# %% [markdown]
# <hr>
# <span style="font-size:20px">Updater Function</span>
# <div style="background-color:black;color:beige">
# <ul>
#     <li><b>Updater Function?</b></li>
#         <ul>
#             <li>def</li>
#                 <ul>
#                     <li>Special function that's called right before Manim captures a new frame</li>
#                 </ul>
#             <li>types</li>
#                <ol>
#                    <li>Mobject updater</li>
#                            <ul>
#                                 <li>can be attached to Mobjects </li>
#                            </ul>
#                    <li>Scene updater</li>
#                            <ul>
#                                 <li>can be attached to  the Scene itself </li>
#                            </ul>
#                    <li>time-dependent updaters</li>
#                            <ul>
#                                 <li>can depend on time passed since last rendered frame</li>
#                            </ul>
#                </ol>
#             <div style="border:1px solid white"><li>usage</li>
#                 <ol>
#                     <li>Mobjects can be made <u>dependent</u> on other mobjects!</li>
#                     <li>Example: make a label move with its mobject:</li>
#                     <li>dot depdendent on its label using add_updater(lambda mobject:moject.next_to(dot,DIRECTION)</li><hr>
#                     <li><div style="background-color:yellow;color:black">def construct(self):<br>
#     &emsp;&emsp;blue_dot = Dot(color=BLUE)<br>
#     &emsp;&emsp;dot_label = Text("Hello dot!").next_to(blue_dot, UP)<br>
#     &emsp;&emsp;dot_label.<span style="color:red;background-color:cyan;font-weight:bold">
#         add_updater(lambda mobject: mobject.next_to(blue_dot, UP))</span><br>
#     &emsp;&emsp;self.add(blue_dot, dot_label)<br>
#     &emsp;&emsp;self.play(blue_dot.animate.shift(RIGHT))<br>
#     &emsp;&emsp;self.play(blue_dot.animate.scale(3))<br>
#     &emsp;&emsp;self.play(blue_dot.animate.center())</li>
#                 </ol></div>
# <table>
#     <th width="333.3333">dot center text center</th>
#     <th width="333.3333">dot at center scale up </th>
#     <th width="333.3333">dot moves text moves</th>
#     <tr>
#         <td><img src="images/dotlabel0.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/dotlabel1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/dotlabel2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>
#             <li><b>different updaters</b></li>
#                 <ul>
#                     <li><div style="border:double  white;padding:2px ;background-color:indigo">
#                         Important: This is valid for up to Manim v0.15.1.
#                         we will likely change it at some point.</div></li>
#                     <li>Mobject Updaters: |example: dot and textlable above|</li>
#                            <ul>
#                                 <li>one or two positional arguments </li>
#                                     <ul>
#                                         <li>first argument: the mobject itself </li>
#                                         <li>second argument: only if named dt: time difference</li>
#                                     </ul>
#                                 <li>arbitrary keyword arguments </li>
#                            </ul>
#                     <li>Scene Updaters: |scene is always time difference updater| </li>
#                             <ul>
#                                 <li>one positional argument  </li>
#                                     <ul>
#                                         <li>(time difference) </li>
#                                     </ul>
#                                 <li>arbitrary keyword arguments</li>
#                             </ul><hr>
#                     <li><div style="border:double cyan;padding:2px ;background-color:maroon">
#                         workflow of combining 3 updaters:time-based,mobject,scene uppdater
#                         within a single scene </div></li>
#                             <ol>
#                                 <li>in the scene, two mobjects ,a dot and an arrow, are to be created</li>
#                                 <li>the arrow is plcaed at the left side of the dot and
#                                     pointing towards it</li>
#                                 <li>attache an updater to the dot which makes the dot move around and
#                                  <li>there will be a scene updater which will make the mobject
#                                     smaller or larger depending on how far away they are from the center</li>
#                             </ol>
#                     <hr>
#                     <li><div style="background-color:yellow;color:indigo">
#                             %%manim -qm --disable_caching AllUpdaterTypes
# &emsp;&emsp;<div style="color:blue;background-color:cyan;border:dotted indigo">
# &emsp; You disable caching primarily to ensure that users see the most recent version of your data, <br>to protect sensitive information, or to easily debug code</div>
# class AllUpdaterTypes(Scene):
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp; remove dots from the scene</div>
#     &emsp;<b>def construct(self):</b><br>
#         &emsp;&emsp;red_dot = Dot(color=RED).shift(LEFT)<br>
#         &emsp;&emsp;pointer = Arrow(ORIGIN, RIGHT).next_to(red_dot, LEFT)
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;the first Direction RIGHT is the pointing direction=rarr&rarr;the second is the location in relation to the dot</div>
#         &emsp;&emsp;pointer.add_updater( lambda mob: mob.next_to(red_dot, LEFT))
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;add an mobject updater so that the arrow attaches to the dot using lambda function </div><hr>
#         &emsp;&emsp;<b>def shifter(mob, <span style="color:red">dt</span>): </b>
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;time dependent updater so there are two arguemnets the first being the object itself and second dt time difference </div>
#         &emsp;&emsp;&emsp;mob.shift(2*dt*RIGHT)
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;dt 1 second - shifted by 2 munits towards the right per second| you can always imagin dt being one second unit</div>
#         &emsp;&emsp;red_dot.add_updater(shifter)
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;after using class function to create a shifter , we need to add the updater so that it will be associated with the dot </div><hr>
#         &emsp;&emsp;<b>def scene_scaler(dt): </b>
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;scene updater is always associated with time different, so the arguemnt must always be dt <br>
#     description: scale mobject depending on distance to origin</div>
#         &emsp;&emsp;&emsp;for mob in self.mobjects:
#         &emsp;&emsp;&emsp;&emsp;mob.set(width=2/(1 + np.linalg.norm(mob.get_center())))
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;after defining an updater class, then we use for loop to gain access to all the mobjects stored in the scene|mobjects<br>
# and then we set the width of the object to some fixed quantity<br> the object will get smaller as it moves farther away from the origin<br>
# formula walkthrough: 2/ (1+n)  the value becomes smaller np.linalg.norm - pythagrian theory , norm of a vector is the length or magnitude of it
# <br> which can be calculated using pythagrain theory, that takes the square root of $x|i^2 + y|j^2 +z|k^2$
# </div>
#         &emsp;self.add_updater(scene_scaler)<hr>
#         &emsp;self.add(red_dot, pointer)<br>
#         &emsp;self.update_self(0)<br>
# &emsp;&emsp;<div style="color:black;border:dotted indigo">
# &emsp;update the scene once, as the object is not scaled correctly: therefore to avoid weird first frame of animation ,
#     the scene needs to be updated</div>
#         &emsp;self.wait(5)<br></div>
# <table>
#     <th width="333.3333">red dot rarr initial position</th>
#     <th width="333.3333">dred dot rarr central position</th>
#     <th width="333.3333">red dot rarr left position </th>
#     <tr>
#         <td><img src="images/reddotarr0.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/reddotarr1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/reddotar2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>
#         </li>
#                 </ul>
# <li><b>Useful hints regarding updaters</b></li>
#         <ul>
#             <li>Common pitfall: assigning updaters in a loop! Due to scoping in Python, loop variable needs to be added explicitly to updater as keyword argument:</li>
#             <li>&emsp;for i in range(len(mob_list):<br>
#             &emsp;&emsp;mob_list[i].add_updater(lambda mob, dt, i=i: <code involving i> </li>
#             <li>Updaters (often) keep running through animations! <b><u>Control</u></b> via .suspend_updating(), .resume_updating()</li>
#             <li>Updaters are resumed automatically after playing an animation</li>
#             <li>time-based updater</li>
#                 <ul>
#                     <li><span style="border:2px double red;padding:2px;border-radius:2px;background-color:white;color:red;
#                             font-weight:bold;font-size:15px">
#                         always use time-based updater!</span></li>
#                     <li>Without time-based updater, wait will produce static frame: pass self.wait(frozen_frame=False) to avoid!</li>
#                 </ul>
#             <li>&emsp;&emsp;<div style="color:black;color:yellow;border:dotted indigo">
#                 %%manim -qm --disable_caching UpdaterAndAnimation<br>
#             &emsp;class UpdaterAndAnimation(Scene):<br>
#                 &emsp;&emsp;def construct(self):<br>
#                     &emsp;&emsp;red_dot = Dot(color=RED).shift(LEFT)<br>
#                     &emsp;&emsp;rotating_square = Square()<br>
#                     &emsp;&emsp;rotating_square.add_updater(lambda mob, dt: mob.rotate(dt*PI))
# &emsp;&emsp;<div style="color:white;border:dotted indigo">
# &emsp;pi*dt 180 $\degree$  rotation per one second</div>
#                     &emsp;&emsp;def shifter(mob, dt):
#                     &emsp;&emsp;&emsp;mob.shift(2*dt*RIGHT)
# &emsp;&emsp;<div style="color:white;border:dotted indigo">
# &emsp;make dot move 2 units RIGHT/sec</div>
#                     &emsp;&emsp;&emsp;red_dot.add_updater(shifter)<br>
#                     &emsp;&emsp;self.add(red_dot, rotating_square)<br>
#                     &emsp;&emsp;self.wait(1)<br>
#                     &emsp;&emsp;red_dot.suspend_updating()<br>
#                     &emsp;&emsp;self.wait(1)<br>
#                     &emsp;&emsp;self.play(red_dot.animate.shift(UP),rotating_square.animate.move_to([-2, -2, 0]))<br>
#                     &emsp;&emsp;self.wait(1)</div></li>
#         </ul>    <br>
# <table>
#     <th width="333.3333">dot at left  | square at center</th>
#     <th width="333.3333">dot at right | square rotates</th>
#     <th width="333.3333">dot moves up | square moves downleft </th>
#     <tr>
#         <td><img src="images/upfuncdotsqu0.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/upfuncdotsqu1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/upfuncdotsqu2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>
#     <li><b>Depending on a number: ValueTracker</b></li>
#         <ul>
#             <li>Depending on a number: ValueTracker</li>
#             <li>ValueTrackers are invisible mobjects that store numbers</li>
#             <li>ValueTrackers are invisible mobjects that store numbers</li>
#             <li>lets us use Manim's animation mechanisms to animate modification of a parameter!</li>
#         </ul>
# </ul>
# </div>
# <hr>

# %% [markdown]
# <div style="background-color:blue;color:cyan;border:10px double white;padding:10px;border-radius:10px">%%manim -qm ValueTrackerMove<br><hr>
# class ValueTrackerMove(Scene):
# &emsp;&emsp;<div style="color:white;border:dotted silver">
# &emsp;whenever you are in a situation, you want to change one of the paremeter .Then value trackers are the way to go basically , they are invisible<br>
#  objects that store numbers and at such you can use manim mechanism to change you can treat
# the value tracker as a regular mobject</div>
#     &emsp;def construct(self):<br>
#         &emsp;&emsp;line = NumberLine(x_range=[-5, 5])<br>
#         &emsp;&emsp;position = ValueTracker(0)
# &emsp;&emsp;<div style="color:white;border:dotted silver">
# &emsp;we construct a numberline , with only tick marks and add a value tracker with initial value set at zero</div>
#         &emsp;&emsp;pointer = Vector(DOWN)<br>
#         &emsp;&emsp;pointer.add_updater( lambda mob: mob.next_to(line.number_to_point(position.get_value()), UP))<br>
#         &emsp;&emsp;pointer.update()<br>
#         &emsp;&emsp;self.add(line, pointer)<br>
#         &emsp;&emsp;self.wait()<br>
#         &emsp;&emsp;self.play(position.animate.set_value(4))<br>
#         &emsp;&emsp;self.play(position.animate.set_value(-2))
# &emsp;&emsp;<div style="color:white;border:dotted silver">
# &emsp;that's why the value trackers are a good choice because it follows and marks the initial and current value</div>
# <hr>
# <table>
#     <th width="333.3333">Pointer at numberline location:0</th>
#     <th width="333.3333">Pointer at numberline location:4</th>
#     <th width="333.3333">Pointer at numberline location:-2 </th>
#     <tr>
#         <td><img src="images/valuetra0.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/valuetra1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/valuetra2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>

# %% [markdown]
# <hr><div style="background-color:white;color:black;border:2px solid yellow;padding:10px;font-weight:bold;
#     border-radius:1px">workflow
#     <ol>
#         <li>Generate a parabola and control it with a value tracker. </li>
#         <li>Therefore, whenever , the value trackers's value changes, the parabola's shape is morphing accordinly</li>
#     </ol>
# %%manim -qm ValueTrackerPlot
# class ValueTrackerPlot(Scene):
# &emsp;&emsp;<div style="color:darkmagenta;border:dotted indigo">
# &emsp;that's why the value trackers are a good choice because it follows and marks the initial and current value</div>
#     &emsp;def construct(self):<br>
#         &emsp;&emsp;<span style="border:1px dashed black;padding:1px">a = ValueTracker(<u><b>1</b></u>)</span><br>
#         &emsp;&emsp;ax = Axes(x_range=[-2, 2, 1], y_range=[-8.5, 8.5, 1], x_length=4, y_length=6)<br>
#         &emsp;&emsp;parabola = ax.plot(lambda x: <span style="background-color:cyan">a.get_value() * x**2</span>, color=RED)<br>
#         &emsp;&emsp;parabola.add_updater(lambda mob: mob.become(ax.plot(lambda x: a.get_value() * x**2, color=RED)))
#         &emsp;&emsp;a_number = DecimalNumber(a.get_value(),color=RED,num_decimal_places=3,show_ellipsis=True)<br>
#         &emsp;&emsp;a_number.add_updater(lambda mob: mob.set_value(a.get_value()).next_to(parabola, RIGHT))
# &emsp;&emsp;<div style="color:darkmagenta;border:dotted indigo">
# <ol>
#     <li><span style="border:1px dashed black;padding:1px">set up a value tracker with initial value <u><b>1</b></u>
#         by assigning it to a variable</span></li>
#     <li>create an ax specifying x and y range/length to ensure aspect ratio</li>
#     <li>plot a parabola using lambda x:equation |a.get_value() is the constant infront of $x^2$
#         <span style="background-color:cyan">&emsp;&rarr;&emsp;$nx^2$;&emsp;&larr;&emsp;</span></li>
#     <li>add updater to parabola using become method </li>
#     <li>numerical readings</li>
#         <ul>
#             <li>use decimal number class to create a number object </li>
#             <li>add updater by assigning its position </li>
#         </ul>
# </ol>
# </div>
#         &emsp;&emsp;self.add(ax, parabola, a_number)<br>
#         &emsp;&emsp;self.play(a.animate.set_value(2))<br>
#         &emsp;&emsp;self.play(a.animate.set_value(-2))<br>
#         &emsp;&emsp;self.play(a.animate.set_value(1))<br>
# </div>
# <table>
#     <th width="333.3333">Value Tracker at 1</th>
#     <th width="333.3333">Value Tracker at 2</th>
#     <th width="333.3333">Value Tracker at -2 </th>
#     <tr>
#         <td><img src="images/para1.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/para2.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#         <td><img src="images/para3.png" alt="1.jpg" width="333.3333" height="333.3333"> </td>
#     </tr>
# </table>

# %% [markdown]
# # 📓-8️⃣ Interactivity

# %% [markdown]
# <ul>
#     <li>OpenGL vs Cairo</li>
#     <ol>
#         <li>def</li>
#             <ul>
#                 <li>OpenGL (Open Graphics Library[4]) is a cross-language, cross-platform application programming interface (API)<br> for rendering 2D and 3D vector graphics. The API is typically used to interact with a graphics <br>processing unit (GPU), to achieve hardware-accelerated rendering.</li>
#             </ul>
#         <li>default: Cairo, can utilize GPU</li>
#         <li>the process of drawing frames and piecing together video is completely different than the traditional Cairo method</li>
#         <li>OpenGL-Mobjects have a different interface</li>
#             <ul>
#                 <li>(e.g., they inherit from OpenGLMobject instead of Mobject),</li>
#                 <li>but most user-facing mobjects (Dot, Axes, …) can be used without changes</li>
#                 <li>(minor) differences for 3D mobjects, camera control, CLI flags</li>
#             </ul>
#         <li>how to activate</li>
#             <ul>
#                 <li>Activate using --renderer=opengl or by setting config.renderer = "opengl</li>
#             </ul>
#         <li>Live render preview</li>
#             <ul>
#                 <li>CLI flag behavior is a bit different (subject to change):</li>
#                 <li>-p / --preview shows a live render preview--write_to_movie must be passed to obtain a file</li>
#                 <li>We can interact with the preview window: add self.interactive_embed() to end of construct!</li>
#                 <li>This halts the preview and spawns an IPython terminal in which further commands can be run</li>
#                 <li> – interactive construct Scene class is available as self; until</li>
#                 <li>Interacting with the render preview Preview window is a pyglet window, supports interaction<br>
#                     – some defaults are implemented</li>
#                 <li>Custom interactions: relevant methods and mobjects Mouse:<br>
#                     Methods: Scene.on_mouse_motion, Scene.on_mouse_scroll, Scene.on_mouse_drag</li>
#             </ul>
#     </ol>
# </ul>

# %% [markdown]
# # 📓-9️⃣ Mathmetical updater

# %% [markdown]
# # Animations Updated

# %%
from IPython.display import Video
Video('video/graph.mp4', width=400, height=280)
# Out:
# <video src="video/graph.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/heart.mp4', width=400, height=280)
# Out:
# <video src="video/heart.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/quadratic1.mp4', width=400, height=280)
# Out:
# <video src="video/quadratic1.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/rose.mp4', width=400, height=280)
# Out:
# <video src="video/rose.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/rosebthem.mp4', width=400, height=280)
# Out:
# <video src="video/rosebthem.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/sin.mp4', width=400, height=280)
# Out:
# <video src="video/sin.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Video
Video('video/wire.mp4', width=400, height=280)
# Out:
# <video src="video/wire.mp4" controls  width="400"  height="280">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # Youtube Link github size limit to prevent uploading large files

# %% [markdown]
# <mark>|cycloid|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtube.com/shorts/G3-PkygVBkY?feature=share

# %% [markdown]
# <mark>|Mandelbrot|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/_iK9PQPizmc

# %% [markdown]
# <mark>|Flashing sun|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/VTNUsp9HD6I

# %% [markdown]
# <mark>|Fractal Dragon|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/bO2CCo0Qnkg

# %% [markdown]
# <mark>|Streamlines|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/zdD1HbdVyds

# %% [markdown]
# <mark>|Lorenz Attractor|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/PTSMesHFajM

# %% [markdown]
# <mark>|Sin Cos|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/SM6w7pZs97g

# %% [markdown]
# <mark>|Fabonocci |</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/I5-SDSwA8Ds

# %% [markdown]
# <mark>|Heart |</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span>https://youtu.be/2oRcDbDfcDA

# %% [markdown]
# <mark>|Flower Petals |</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/GNb5uQsRos8

# %% [markdown]
# <mark>|Function|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/WQZmT1ZQVVE

# %% [markdown]
# <mark>|Sin|</mark> &emsp;&emsp;&rarr;&emsp;&emsp; </span> https://youtu.be/HI3WycUvoAE
